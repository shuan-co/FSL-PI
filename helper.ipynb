# %% [markdown]
# ## PLAYGROUND TEST

# %%
from google.protobuf.json_format import MessageToJson
import mediapipe as mp
import cv2
#pip install mediapipe - -user

# LANDMARK
import json

# %%
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands
# For webcam input:
cap = cv2.VideoCapture(0)

# For Video Input
# video = "./dataset/clips/85/0.MOV"
# cap = cv2.VideoCapture(video)

# %%
with mp_hands.Hands(max_num_hands=2,
                    min_detection_confidence=0.5,
                    min_tracking_confidence=0.5) as hands:
  print(cap.isOpened())
  while cap.isOpened():
    success, image = cap.read()
    if not success:
      print("Ignoring empty camera frame.")

    image = cv2.cvtColor(cv2.flip(image, 1), cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = hands.process(image)

    # DETECT LANDMARKS
    if results.multi_hand_landmarks:
      jsonObj = MessageToJson(results.multi_hand_landmarks[0])
      lmk = json.loads(jsonObj)['landmark']
      print(len(lmk))  # lmk = hand's landmark

# Draw the hand annotations on the image.
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    if results.multi_hand_landmarks:
      for hand_landmarks in results.multi_hand_landmarks:
        mp_drawing.draw_landmarks(
            image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
    cv2.imshow('MediaPipe Hands', image)
    if cv2.waitKey(5) & 0xFF == 27:
      break
cap.release()
# Out:
# True
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21
# 21

# %%
import pandas as pd
import numpy as np

# %%
# FEATURE EXTRACTOR
def distance_between(p1_loc, p2_loc):
    jsonObj = MessageToJson(results.multi_hand_landmarks[0])
    lmk = json.loads(jsonObj)['landmark']
    p1 = pd.DataFrame(lmk).to_numpy()[p1_loc]
    p2 = pd.DataFrame(lmk).to_numpy()[p2_loc]
    squared_dist = np.sum((p1-p2)**2, axis=0)
    return np.sqrt(squared_dist)


def landmark_to_dist_emb(results):
    jsonObj = MessageToJson(results.multi_hand_landmarks[0])
    lmk = json.loads(jsonObj)['landmark']

    emb = np.array([
        # thumb to finger tip
        distance_between(4, 8),
        distance_between(4, 12),
        distance_between(4, 16),
        distance_between(4, 20),
        # wrist to finger tip
        distance_between(4, 0),
        distance_between(8, 0),
        distance_between(12, 0),
        distance_between(16, 0),
        distance_between(20, 0),
        # tip to tip (specific to this application)
        distance_between(8, 12),
        distance_between(12, 16),
        # within finger joint (detect bending)
        distance_between(1, 4),
        distance_between(8, 5),
        distance_between(12, 9),
        distance_between(16, 13),
        distance_between(20, 17),
        # distance from each tip to thumb joint
        distance_between(2, 8),
        distance_between(2, 12),
        distance_between(2, 16),
        distance_between(2, 20)
    ])
    # use np normalize, as min_max may create confusion that the closest fingers has 0 distance
    emb_norm = emb / np.linalg.norm(emb)
    return emb_norm

# %%
# SCRIPT FILE FORMATTER
import random
import string
import shutil
import os

def generate_random_uid():
    """Generate a random UID."""
    return ''.join(random.choices(string.ascii_lowercase + string.digits, k=8))


def rename_videos(directory_path):
    """Rename videos in the specified directory."""
    for root, dirs, files in os.walk(directory_path):
        for file in files:
            if file.endswith(".MOV"):
                old_path = os.path.join(root, file)
                new_uid = generate_random_uid()
                new_name = f"{new_uid}_0.MOV"
                new_path = os.path.join(root, new_name)

                shutil.move(old_path, new_path)
                print(f"Renamed: {old_path} to {new_path}")


# Specify the directory containing the videos
directory_path = './dataset/clips/85'

# Call the function to rename the videos
rename_videos(directory_path)
# Out:
# Renamed: ./dataset/clips/85\0f0lzm9c_0.MOV to ./dataset/clips/85\p5ga19wa_0.MOV
# Renamed: ./dataset/clips/85\0mb6to35_0.MOV to ./dataset/clips/85\mato6gvs_0.MOV
# Renamed: ./dataset/clips/85\0om5g1it_0.MOV to ./dataset/clips/85\fdpnld0t_0.MOV
# Renamed: ./dataset/clips/85\394m2pcf_0.MOV to ./dataset/clips/85\r4znhltx_0.MOV
# Renamed: ./dataset/clips/85\3r4pmpw0_0.MOV to ./dataset/clips/85\inl5n07c_0.MOV
# Renamed: ./dataset/clips/85\5r1fmott_0.MOV to ./dataset/clips/85\f9r9bsva_0.MOV
# Renamed: ./dataset/clips/85\77o8wpno_0.MOV to ./dataset/clips/85\qygo7g5s_0.MOV
# Renamed: ./dataset/clips/85\801rxjav_0.MOV to ./dataset/clips/85\4asdlwz1_0.MOV
# Renamed: ./dataset/clips/85\9xu0jpcs_0.MOV to ./dataset/clips/85\11taoceh_0.MOV
# Renamed: ./dataset/clips/85\aklxt2hx_0.MOV to ./dataset/clips/85\940bqr4z_0.MOV
# Renamed: ./dataset/clips/85\d8hlk6ts_0.MOV to ./dataset/clips/85\i6641z1q_0.MOV
# Renamed: ./dataset/clips/85\gnyv9lo8_0.MOV to ./dataset/clips/85\vvzajti5_0.MOV
# Renamed: ./dataset/clips/85\hhc0oi3e_0.MOV to ./dataset/clips/85\opunh4zs_0.MOV
# Renamed: ./dataset/clips/85\jyg7an9x_0.MOV to ./dataset/clips/85\titl2dvs_0.MOV
# Renamed: ./dataset/clips/85\o83jzi98_0.MOV to ./dataset/clips/85\fx5jgfby_0.MOV
# Renamed: ./dataset/clips/85\ot0622lk_0.MOV to ./dataset/clips/85\4wjsa5wq_0.MOV
# Renamed: ./dataset/clips/85\pojpmybt_0.MOV to ./dataset/clips/85\tzd3o8eu_0.MOV
# Renamed: ./dataset/clips/85\r4i6ds1s_0.MOV to ./dataset/clips/85\9dppbec3_0.MOV
# Renamed: ./dataset/clips/85\uk793771_0.MOV to ./dataset/clips/85\gwa534to_0.MOV
# Renamed: ./dataset/clips/85\unct38mn_0.MOV to ./dataset/clips/85\nz7q913t_0.MOV

# %%
import os
import cv2
import mediapipe as mp

arr = os.listdir('./dataset/clips/85')
video_class_all = []
landmark_npy_all = []
handnn = mp.solutions.hands.Hands(
    max_num_hands=2, min_detection_confidence=0.6, min_tracking_confidence=0.6)

for idx, eachVideo in enumerate(arr):
    landmark_npy_single = []  # Reset for each video
    video = './dataset/clips/85/' + eachVideo
    cap = cv2.VideoCapture(video)
    video_class_all.append(int(video.split('_')[1].split('.')[0]))
    print(video)
    while cap.isOpened():
        success, image = cap.read()
        if not success:
            break

        image = cv2.cvtColor(cv2.flip(image, 1), cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        results = handnn.process(image)
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                landmark_npy_single.append(landmark_to_dist_emb(results))

    # Append landmarks for each video only once
    landmark_npy_all.append(landmark_npy_single)

    cap.release()

    if ((idx + 1) % 10) == 0:
        print(f'Finished for {(idx + 1)} videos')

print(f'Finished for total {len(arr)} videos. Completed.')
# Out:
# ./dataset/clips/85/11taoceh_0.MOV
# ./dataset/clips/85/4asdlwz1_0.MOV
# ./dataset/clips/85/4wjsa5wq_0.MOV
# ./dataset/clips/85/940bqr4z_0.MOV
# ./dataset/clips/85/9dppbec3_0.MOV
# ./dataset/clips/85/f9r9bsva_0.MOV
# ./dataset/clips/85/fdpnld0t_0.MOV
# ./dataset/clips/85/fx5jgfby_0.MOV
# ./dataset/clips/85/gwa534to_0.MOV
# ./dataset/clips/85/i6641z1q_0.MOV
# Finished for 10 videos
# ./dataset/clips/85/inl5n07c_0.MOV
# ./dataset/clips/85/mato6gvs_0.MOV
# ./dataset/clips/85/nz7q913t_0.MOV
# ./dataset/clips/85/opunh4zs_0.MOV
# ./dataset/clips/85/p5ga19wa_0.MOV
# ./dataset/clips/85/qygo7g5s_0.MOV
# ./dataset/clips/85/r4znhltx_0.MOV
# ./dataset/clips/85/titl2dvs_0.MOV
# ./dataset/clips/85/tzd3o8eu_0.MOV
# ./dataset/clips/85/vvzajti5_0.MOV
# Finished for 20 videos
# Finished for total 20 videos. Completed.

# %%
from keras.preprocessing.sequence import pad_sequences
import math


def skip_frame(landmark_npy_all, frame=50):
    new_lmk_array = []


    for each in landmark_npy_all:
        if len(each) <= frame:
        # if its less than frame, dont need to skip
            new_lmk_array.append(each)
        else:
        # skip frame by ceiling
            to_round = math.ceil(len(each)/frame)
            new_lmk_array.append(each[::to_round])
    return new_lmk_array

new_lmk_array = skip_frame(landmark_npy_all)
train_x = pad_sequences(new_lmk_array, padding='post', maxlen=50, dtype='float32')

# %%
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
classes = len(set(video_class_all))
feature_len = 20
max_len = 50
# hot encode output
train_y = to_categorical([i-1 for i in video_class_all], num_classes=classes)
print('Training y with shape of: ', train_y.shape)
print('Training x with shape of: ', train_x.shape)
X_train, X_test, y_train, y_test = train_test_split(train_x, train_y, test_size=0.2)
print("----")
print("Shape of X_train: ", X_train.shape)
print("Shape of y_train: ", y_train.shape)
print("Shape of X_test: ", X_train.shape)
print("Shape of y_test: ", y_train.shape)

print(X_train[0].shape)
# Out:
# Training y with shape of:  (20, 1)
# Training x with shape of:  (20, 50, 20)
# ----
# Shape of X_train:  (16, 50, 20)
# Shape of y_train:  (16, 1)
# Shape of X_test:  (16, 50, 20)
# Shape of y_test:  (16, 1)
# (50, 20)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense, BatchNormalization, Activation
from keras.callbacks import LearningRateScheduler

# %%
model = Sequential()
model.add(LSTM(256, return_sequences=True, input_shape=(max_len, feature_len)))
model.add(Dropout(0.25))
model.add(LSTM(256, return_sequences=True))
model.add(Dropout(0.25))
model.add(LSTM(128, return_sequences=False))
model.add(Dense(64))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(classes, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()


def lrSchedule(epoch):
    lr = 0.001
    if epoch > 200:
        lr *= 0.0005
    elif epoch > 120:
        lr *= 0.005
    elif epoch > 50:
        lr *= 0.01
    elif epoch > 30:
        lr *= 0.1

    print('Learning rate: ', lr)
    return lr


LRScheduler = LearningRateScheduler(lrSchedule)
callbacks_list = [LRScheduler]
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 50, 256)           283648
#
#  dropout_4 (Dropout)         (None, 50, 256)           0
#
#  lstm_7 (LSTM)               (None, 50, 256)           525312
#
#  dropout_5 (Dropout)         (None, 50, 256)           0
#
#  lstm_8 (LSTM)               (None, 128)               197120
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  batch_normalization_2 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_2 (Activation)   (None, 64)                0
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 1014657 (3.87 MB)
# Trainable params: 1014529 (3.87 MB)
# Non-trainable params: 128 (512.00 Byte)
# _________________________________________________________________

# %%
verbose, epochs, batch_size = 1, 300, 8
model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs=epochs, batch_size=batch_size, verbose=verbose, shuffle=True)
# Out:
# Learning rate:  0.001
# Epoch 1/300
# e:\Compilers\Python\3.11.1\Lib\site-packages\tensorflow\python\util\dispatch.py:1176: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(8, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return dispatch_target(*args, **kwargs)
# 2/2 [==============================] - ETA: 0s - loss: 0.0000e+00 - accuracy: 1.0000
# e:\Compilers\Python\3.11.1\Lib\site-packages\tensorflow\python\util\dispatch.py:1176: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return dispatch_target(*args, **kwargs)
# 2/2 [==============================] - 6s 1s/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 2/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 3/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 4/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 5/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 6/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 7/300
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 8/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 9/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 10/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 11/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 12/300
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 13/300
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 14/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 15/300
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 16/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 17/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 18/300
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 19/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 20/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 21/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 22/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 23/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 24/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 25/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 26/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 27/300
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 28/300
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 29/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 30/300
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 31/300
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.0001
# Epoch 32/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 33/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 34/300
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 35/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 36/300
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 37/300
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 38/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 39/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 40/300
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 41/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 42/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 43/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 44/300
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 45/300
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 46/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 47/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 48/300
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 49/300
# 2/2 [==============================] - 0s 97ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 50/300
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 51/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  1e-05
# Epoch 52/300
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 53/300
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 54/300
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 55/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 56/300
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 57/300
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 58/300
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 59/300
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 60/300
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 61/300
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 62/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 63/300
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 64/300
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 65/300
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 66/300
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 67/300
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 68/300
# 2/2 [==============================] - 0s 122ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 69/300
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 70/300
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 71/300
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 72/300
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 73/300
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 74/300
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 75/300
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 76/300
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 77/300
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 78/300
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 79/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 80/300
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 81/300
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 82/300
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 83/300
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 84/300
# 2/2 [==============================] - 0s 119ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 85/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 86/300
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 87/300
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 88/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 89/300
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 90/300
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 91/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 92/300
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 93/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 94/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 95/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 96/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 97/300
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 98/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 99/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 100/300
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 101/300
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 102/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 103/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 104/300
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 105/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 106/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 107/300
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 108/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 109/300
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 110/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 111/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 112/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 113/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 114/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 115/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 116/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 117/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 118/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 119/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 120/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 121/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  5e-06
# Epoch 122/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 123/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 124/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 125/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 126/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 127/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 128/300
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 129/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 130/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 131/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 132/300
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 133/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 134/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 135/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 136/300
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 137/300
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 138/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 139/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 140/300
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 141/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 142/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 143/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 144/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 145/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 146/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 147/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 148/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 149/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 150/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 151/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 152/300
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 153/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 154/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 155/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 156/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 157/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 158/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 159/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 160/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 161/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 162/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 163/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 164/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 165/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 166/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 167/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 168/300
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 169/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 170/300
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 171/300
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 172/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 173/300
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 174/300
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 175/300
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 176/300
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 177/300
# 2/2 [==============================] - 0s 108ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 178/300
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 179/300
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 180/300
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 181/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 182/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 183/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 184/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 185/300
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 186/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 187/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 188/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 189/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 190/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 191/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 192/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 193/300
# 2/2 [==============================] - 0s 115ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 194/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 195/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 196/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 197/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 198/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 199/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 200/300
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 201/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-07
# Epoch 202/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 203/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 204/300
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 205/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 206/300
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 207/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 208/300
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 209/300
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 210/300
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 211/300
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 212/300
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 213/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 214/300
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 215/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 216/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 217/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 218/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 219/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 220/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 221/300
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 222/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 223/300
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 224/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 225/300
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 226/300
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 227/300
# 2/2 [==============================] - 0s 114ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 228/300
# 2/2 [==============================] - 0s 116ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 229/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 230/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 231/300
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 232/300
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 233/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 234/300
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 235/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 236/300
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 237/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 238/300
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 239/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 240/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 241/300
# 2/2 [==============================] - 0s 98ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 242/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 243/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 244/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 245/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 246/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 247/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 248/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 249/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 250/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 251/300
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 252/300
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 253/300
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 254/300
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 255/300
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 256/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 257/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 258/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 259/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 260/300
# 2/2 [==============================] - 0s 118ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 261/300
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 262/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 263/300
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 264/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 265/300
# 2/2 [==============================] - 0s 112ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 266/300
# 2/2 [==============================] - 0s 121ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 267/300
# 2/2 [==============================] - 0s 103ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 268/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 269/300
# 2/2 [==============================] - 0s 109ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 270/300
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 271/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 272/300
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 273/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 274/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 275/300
# 2/2 [==============================] - 0s 106ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 276/300
# 2/2 [==============================] - 0s 117ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 277/300
# 2/2 [==============================] - 0s 113ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 278/300
# 2/2 [==============================] - 0s 110ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 279/300
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 280/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 281/300
# 2/2 [==============================] - 0s 105ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 282/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 283/300
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 284/300
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 285/300
# 2/2 [==============================] - 0s 111ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 286/300
# 2/2 [==============================] - 0s 120ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 287/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 288/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 289/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 290/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 291/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 292/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 293/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 294/300
# 2/2 [==============================] - 0s 104ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 295/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 296/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 297/300
# 2/2 [==============================] - 0s 101ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 298/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 299/300
# 2/2 [==============================] - 0s 99ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 300/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000 - lr: 5.0000e-07

# %%
model.save("fsl-pi.h5")
# Out:
# e:\Compilers\Python\3.11.1\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from keras.models import load_model

# Replace 'your_model_path' with the actual path to your trained model
trained_model = load_model('./fsl-pi.h5')

# %%
import cv2
import mediapipe as mp
import numpy as np
from keras.models import load_model

# Load your trained model
trained_model = load_model('./fsl-pi.h5')

mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# For webcam input:
cap = cv2.VideoCapture(0)

with mp_hands.Hands(max_num_hands=1,
                    min_detection_confidence=0.5,
                    min_tracking_confidence=0.5) as hands:
    while cap.isOpened():
        success, image = cap.read()
        if not success:
            print("Ignoring empty camera frame.")
            continue

        image = cv2.cvtColor(cv2.flip(image, 1), cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        results = hands.process(image)

        # Draw the hand annotations on the image.
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                mp_drawing.draw_landmarks(
                    image, hand_landmarks, mp_hands.HAND_CONNECTIONS)

                # Extract hand landmarks and prepare them for prediction
                landmarks = np.array([[lm.x, lm.y, lm.z]
                                     for lm in hand_landmarks.landmark])
                landmarks = landmarks.flatten()
                landmarks = np.expand_dims(landmarks, axis=0)

                # Make prediction using the trained model
                prediction = trained_model.predict(landmarks)

                # Print the prediction
                print("Prediction:", prediction)

        cv2.imshow('MediaPipe Hands', image)
        if cv2.waitKey(5) & 0xFF == 27:
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 43
#      40 landmarks = np.expand_dims(landmarks, axis=0)
#      42 # Make prediction using the trained model
# ---> 43 prediction = trained_model.predict(landmarks)
#      45 # Print the prediction
#      46 print("Prediction:", prediction)
#
# File e:\Compilers\Python\3.11.1\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_fileseeq5pt6.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__predict_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "e:\Compilers\Python\3.11.1\Lib\site-packages\keras\src\engine\training.py", line 2341, in predict_function  *
#         return step_function(self, iterator)
#     File "e:\Compilers\Python\3.11.1\Lib\site-packages\keras\src\engine\training.py", line 2327, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "e:\Compilers\Python\3.11.1\Lib\site-packages\keras\src\engine\training.py", line 2315, in run_step  **
#         outputs = model.predict_step(data)
#     File "e:\Compilers\Python\3.11.1\Lib\site-packages\keras\src\engine\training.py", line 2283, in predict_step
#         return self(x, training=False)
#     File "e:\Compilers\Python\3.11.1\Lib\site-packages\keras\src\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "e:\Compilers\Python\3.11.1\Lib\site-packages\keras\src\engine\input_spec.py", line 298, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential_2" is incompatible with the layer: expected shape=(None, 50, 20), found shape=(None, 63)
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## IMAGE DATA SCRAPING

# %%
# !pip install simple_image_download

# %%
from simple_image_download import simple_image_download as simp
response = simp.simple_image_download
keywords = ["something here", "something here"]

# keyword, n images
for kw in keywords:
    response().download(kw, 300)

# %% [markdown]
# ## LABEL DATASET

# %%
# !pip install labelImg

# %%
# !labelImg

# %% [markdown]
# ## .MOV TO IMAGES

# %%
import cv2


def convert_video_to_images(video_path, output_path, start_time_seconds=2):
    # Open the video file
    cap = cv2.VideoCapture(video_path)

    # Get the frames per second (fps) and total number of frames
    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the starting frame based on the start time
    start_frame = int(start_time_seconds * fps)

    # Set the video capture object to start from the calculated frame
    cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)

    # Loop through the frames and save them as images
    current_frame = start_frame
    while current_frame < total_frames:
        ret, frame = cap.read()
        if not ret:
            break

        # Save the frame as an image
        image_path = f"{output_path}/frame_{current_frame:04d}.png"
        cv2.imwrite(image_path, frame)

        # Increment the current frame
        current_frame += 1

    # Release the video capture object
    cap.release()


# Example usage:
video_path = 'path/to/your/video.mov'
output_path = 'path/to/output/folder'
convert_video_to_images(video_path, output_path, start_time_seconds=2)

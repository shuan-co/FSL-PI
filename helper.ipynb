# %% [markdown]
# ## PLAYGROUND TEST

# %%
import pandas as pd
import numpy as np
from google.protobuf.json_format import MessageToJson
# FEATURE EXTRACTOR


def distance_between(p1_loc, p2_loc):
    jsonObj = MessageToJson(results.multi_hand_landmarks[0])
    lmk = json.loads(jsonObj)['landmark']
    p1 = pd.DataFrame(lmk).to_numpy()[p1_loc]
    p2 = pd.DataFrame(lmk).to_numpy()[p2_loc]
    squared_dist = np.sum((p1-p2)**2, axis=0)
    return np.sqrt(squared_dist)


def landmark_to_dist_emb(results):
    jsonObj = MessageToJson(results.multi_hand_landmarks[0])
    lmk = json.loads(jsonObj)['landmark']

    emb = np.array([
        # thumb to finger tip
        distance_between(4, 8),
        distance_between(4, 12),
        distance_between(4, 16),
        distance_between(4, 20),
        # wrist to finger tip
        distance_between(4, 0),
        distance_between(8, 0),
        distance_between(12, 0),
        distance_between(16, 0),
        distance_between(20, 0),
        # tip to tip (specific to this application)
        distance_between(8, 12),
        distance_between(12, 16),
        # within finger joint (detect bending)
        distance_between(1, 4),
        distance_between(8, 5),
        distance_between(12, 9),
        distance_between(16, 13),
        distance_between(20, 17),
        # distance from each tip to thumb joint
        distance_between(2, 8),
        distance_between(2, 12),
        distance_between(2, 16),
        distance_between(2, 20)
    ])
    # use np normalize, as min_max may create confusion that the closest fingers has 0 distance
    emb_norm = emb / np.linalg.norm(emb)
    return emb_norm

# %%
import mediapipe as mp
import cv2
#pip install mediapipe - -user

# LANDMARK
import json

# %%
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands
# For webcam input:
#cap = cv2.VideoCapture(0)

# For Video Input
# video = "./dataset/clips/85/0.MOV"
# cap = cv2.VideoCapture(video)

# %%
with mp_hands.Hands(max_num_hands=2,
                    min_detection_confidence=0.5,
                    min_tracking_confidence=0.5) as hands:
  print(cap.isOpened())
  while cap.isOpened():
    success, image = cap.read()
    if not success:
      print("Ignoring empty camera frame.")

    image = cv2.cvtColor(cv2.flip(image, 1), cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = hands.process(image)

    # DETECT LANDMARKS
    if results.multi_hand_landmarks:

      #print(landmark_to_dist_emb(results).shape) process input
      jsonObj = MessageToJson(results.multi_hand_landmarks[0])
      lmk = json.loads(jsonObj)['landmark']
      
      #print(len(lmk))  # lmk = hand's landmark

# Draw the hand annotations on the image.
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    if results.multi_hand_landmarks:
      for hand_landmarks in results.multi_hand_landmarks:
        mp_drawing.draw_landmarks(
            image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
    cv2.imshow('MediaPipe Hands', image)
    if cv2.waitKey(5) & 0xFF == 27:
      break
cap.release()

# %%
import random
import string
import shutil
import os


def generate_random_uid():
    """Generate a random UID."""
    return ''.join(random.choices(string.ascii_lowercase + string.digits, k=8))


def rename_videos(source_directory, destination_directory, idx):
    """Rename videos in the specified directory."""
    for root, dirs, files in os.walk(source_directory):
        for file in files:
            if file.endswith(".MOV"):
                old_path = os.path.join(root, file)
                new_uid = generate_random_uid()
                new_name = f"{new_uid}_{idx}.MOV"
                new_path = os.path.join(destination_directory, new_name)

                shutil.copy(old_path, new_path)
                print(f"Renamed and copied: {old_path} to {new_path}")


# Specify the source directory containing the videos
source_directory = './dataset/clips/'

# Specify the destination directory for the renamed videos
destination_directory = './dataset/processed/'

# Create the destination directory if it doesn't exist
os.makedirs(destination_directory, exist_ok=True)

# Call the function to rename and copy the videos
targetSets = [85, 86, 89, 94]

for idx, target in enumerate(targetSets):
    print("Renaming Target Set: ", target)
    rename_videos(source_directory + str(target), destination_directory, idx)
    print("\n\n")
# Out:
# Renaming Target Set:  85
# Renamed and copied: ./dataset/clips/85\11taoceh_0.MOV to ./dataset/processed/kjkvopt0_0.MOV
# Renamed and copied: ./dataset/clips/85\4asdlwz1_0.MOV to ./dataset/processed/qtww2hem_0.MOV
# Renamed and copied: ./dataset/clips/85\4wjsa5wq_0.MOV to ./dataset/processed/8i5ntven_0.MOV
# Renamed and copied: ./dataset/clips/85\940bqr4z_0.MOV to ./dataset/processed/qmfbonj9_0.MOV
# Renamed and copied: ./dataset/clips/85\9dppbec3_0.MOV to ./dataset/processed/a7kgnkqf_0.MOV
# Renamed and copied: ./dataset/clips/85\f9r9bsva_0.MOV to ./dataset/processed/nyp3snlr_0.MOV
# Renamed and copied: ./dataset/clips/85\fdpnld0t_0.MOV to ./dataset/processed/bbd6kbwj_0.MOV
# Renamed and copied: ./dataset/clips/85\fx5jgfby_0.MOV to ./dataset/processed/5hqc7gj1_0.MOV
# Renamed and copied: ./dataset/clips/85\gwa534to_0.MOV to ./dataset/processed/v3vnkow7_0.MOV
# Renamed and copied: ./dataset/clips/85\i6641z1q_0.MOV to ./dataset/processed/hkvo9l68_0.MOV
# Renamed and copied: ./dataset/clips/85\inl5n07c_0.MOV to ./dataset/processed/wa5qsdjj_0.MOV
# Renamed and copied: ./dataset/clips/85\mato6gvs_0.MOV to ./dataset/processed/dabw447j_0.MOV
# Renamed and copied: ./dataset/clips/85\nz7q913t_0.MOV to ./dataset/processed/tk481pwe_0.MOV
# Renamed and copied: ./dataset/clips/85\opunh4zs_0.MOV to ./dataset/processed/jbmb88kg_0.MOV
# Renamed and copied: ./dataset/clips/85\p5ga19wa_0.MOV to ./dataset/processed/ge08bs2g_0.MOV
# Renamed and copied: ./dataset/clips/85\qygo7g5s_0.MOV to ./dataset/processed/svy5ct8l_0.MOV
# Renamed and copied: ./dataset/clips/85\r4znhltx_0.MOV to ./dataset/processed/gok3tvt7_0.MOV
# Renamed and copied: ./dataset/clips/85\titl2dvs_0.MOV to ./dataset/processed/3sxbzdo5_0.MOV
# Renamed and copied: ./dataset/clips/85\tzd3o8eu_0.MOV to ./dataset/processed/52c8ry5q_0.MOV
# Renamed and copied: ./dataset/clips/85\vvzajti5_0.MOV to ./dataset/processed/cirfj60f_0.MOV
#
#
#
# Renaming Target Set:  86
# Renamed and copied: ./dataset/clips/86\0.MOV to ./dataset/processed/f6g3b499_1.MOV
# Renamed and copied: ./dataset/clips/86\1.MOV to ./dataset/processed/khuxq6pp_1.MOV
# Renamed and copied: ./dataset/clips/86\10.MOV to ./dataset/processed/3bpyl4rn_1.MOV
# Renamed and copied: ./dataset/clips/86\11.MOV to ./dataset/processed/pp0y3x6y_1.MOV
# Renamed and copied: ./dataset/clips/86\12.MOV to ./dataset/processed/c7hh65ox_1.MOV
# Renamed and copied: ./dataset/clips/86\13.MOV to ./dataset/processed/6imffdjk_1.MOV
# Renamed and copied: ./dataset/clips/86\14.MOV to ./dataset/processed/s4pxb305_1.MOV
# Renamed and copied: ./dataset/clips/86\15.MOV to ./dataset/processed/34rd17y8_1.MOV
# Renamed and copied: ./dataset/clips/86\16.MOV to ./dataset/processed/x50u6nw7_1.MOV
# Renamed and copied: ./dataset/clips/86\17.MOV to ./dataset/processed/vhznijcj_1.MOV
# Renamed and copied: ./dataset/clips/86\18.MOV to ./dataset/processed/27npt95d_1.MOV
# Renamed and copied: ./dataset/clips/86\19.MOV to ./dataset/processed/hm8uob9i_1.MOV
# Renamed and copied: ./dataset/clips/86\2.MOV to ./dataset/processed/73ud2nmr_1.MOV
# Renamed and copied: ./dataset/clips/86\3.MOV to ./dataset/processed/l881vgip_1.MOV
# Renamed and copied: ./dataset/clips/86\4.MOV to ./dataset/processed/0pfsgw9z_1.MOV
# Renamed and copied: ./dataset/clips/86\5.MOV to ./dataset/processed/xq8f9cmw_1.MOV
# Renamed and copied: ./dataset/clips/86\6.MOV to ./dataset/processed/aghmvdlk_1.MOV
# Renamed and copied: ./dataset/clips/86\7.MOV to ./dataset/processed/1qkjrxmx_1.MOV
# Renamed and copied: ./dataset/clips/86\8.MOV to ./dataset/processed/065kdgwe_1.MOV
# Renamed and copied: ./dataset/clips/86\9.MOV to ./dataset/processed/4x9hsurv_1.MOV
#
#
#
# Renaming Target Set:  89
# Renamed and copied: ./dataset/clips/89\0.MOV to ./dataset/processed/5oqq3sxx_2.MOV
# Renamed and copied: ./dataset/clips/89\1.MOV to ./dataset/processed/1nlndxyg_2.MOV
# Renamed and copied: ./dataset/clips/89\10.MOV to ./dataset/processed/syzwqd1m_2.MOV
# Renamed and copied: ./dataset/clips/89\11.MOV to ./dataset/processed/an2fk0t1_2.MOV
# Renamed and copied: ./dataset/clips/89\12.MOV to ./dataset/processed/61bfyw5j_2.MOV
# Renamed and copied: ./dataset/clips/89\13.MOV to ./dataset/processed/51ktgnv4_2.MOV
# Renamed and copied: ./dataset/clips/89\14.MOV to ./dataset/processed/d5iqenml_2.MOV
# Renamed and copied: ./dataset/clips/89\15.MOV to ./dataset/processed/s7nzxp24_2.MOV
# Renamed and copied: ./dataset/clips/89\16.MOV to ./dataset/processed/ffrtt1su_2.MOV
# Renamed and copied: ./dataset/clips/89\17.MOV to ./dataset/processed/l35smdsa_2.MOV
# Renamed and copied: ./dataset/clips/89\18.MOV to ./dataset/processed/a37t1dqq_2.MOV
# Renamed and copied: ./dataset/clips/89\19.MOV to ./dataset/processed/1v4bggyw_2.MOV
# Renamed and copied: ./dataset/clips/89\2.MOV to ./dataset/processed/k9n9op2v_2.MOV
# Renamed and copied: ./dataset/clips/89\3.MOV to ./dataset/processed/jdbsmtvn_2.MOV
# Renamed and copied: ./dataset/clips/89\4.MOV to ./dataset/processed/jog89l05_2.MOV
# Renamed and copied: ./dataset/clips/89\5.MOV to ./dataset/processed/3sa851bk_2.MOV
# Renamed and copied: ./dataset/clips/89\6.MOV to ./dataset/processed/zin4pkdn_2.MOV
# Renamed and copied: ./dataset/clips/89\7.MOV to ./dataset/processed/87ka6p0q_2.MOV
# Renamed and copied: ./dataset/clips/89\8.MOV to ./dataset/processed/4vf5637m_2.MOV
# Renamed and copied: ./dataset/clips/89\9.MOV to ./dataset/processed/p9vuxyea_2.MOV
#
#
#
# Renaming Target Set:  94
# Renamed and copied: ./dataset/clips/94\0.MOV to ./dataset/processed/35z9bqff_3.MOV
# Renamed and copied: ./dataset/clips/94\1.MOV to ./dataset/processed/gb5jmo9t_3.MOV
# Renamed and copied: ./dataset/clips/94\10.MOV to ./dataset/processed/fmafjf5t_3.MOV
# Renamed and copied: ./dataset/clips/94\11.MOV to ./dataset/processed/lkvfng3n_3.MOV
# Renamed and copied: ./dataset/clips/94\12.MOV to ./dataset/processed/ig8bnk6w_3.MOV
# Renamed and copied: ./dataset/clips/94\13.MOV to ./dataset/processed/nkth7huj_3.MOV
# Renamed and copied: ./dataset/clips/94\14.MOV to ./dataset/processed/dzn77ofm_3.MOV
# Renamed and copied: ./dataset/clips/94\15.MOV to ./dataset/processed/okt1gdn2_3.MOV
# Renamed and copied: ./dataset/clips/94\16.MOV to ./dataset/processed/3n4kpfnk_3.MOV
# Renamed and copied: ./dataset/clips/94\17.MOV to ./dataset/processed/krwrfq8m_3.MOV
# Renamed and copied: ./dataset/clips/94\18.MOV to ./dataset/processed/xgygn5zm_3.MOV
# Renamed and copied: ./dataset/clips/94\19.MOV to ./dataset/processed/lepwanp5_3.MOV
# Renamed and copied: ./dataset/clips/94\2.MOV to ./dataset/processed/afdwl1gi_3.MOV
# Renamed and copied: ./dataset/clips/94\3.MOV to ./dataset/processed/qgq8hiwk_3.MOV
# Renamed and copied: ./dataset/clips/94\4.MOV to ./dataset/processed/jssu5n4y_3.MOV
# Renamed and copied: ./dataset/clips/94\5.MOV to ./dataset/processed/mt3gyd7d_3.MOV
# Renamed and copied: ./dataset/clips/94\6.MOV to ./dataset/processed/42bqlsuv_3.MOV
# Renamed and copied: ./dataset/clips/94\7.MOV to ./dataset/processed/e4ec5kar_3.MOV
# Renamed and copied: ./dataset/clips/94\8.MOV to ./dataset/processed/aabz9a7a_3.MOV
# Renamed and copied: ./dataset/clips/94\9.MOV to ./dataset/processed/u12hlx03_3.MOV

# %%
import os
import cv2
import mediapipe as mp

arr = os.listdir('./dataset/processed')
video_class_all = []
landmark_npy_all = []
handnn = mp.solutions.hands.Hands(
    max_num_hands=2, min_detection_confidence=0.6, min_tracking_confidence=0.6)

for idx, eachVideo in enumerate(arr):
    landmark_npy_single = []  # Reset for each video
    video = './dataset/processed/' + eachVideo
    cap = cv2.VideoCapture(video)
    video_class_all.append(int(video.split('_')[1].split('.')[0]))
    print(video)
    while cap.isOpened():
        success, image = cap.read()
        if not success:
            break

        image = cv2.cvtColor(cv2.flip(image, 1), cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        results = handnn.process(image)
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                landmark_npy_single.append(landmark_to_dist_emb(results))

    # Append landmarks for each video only once
    landmark_npy_all.append(landmark_npy_single)

    cap.release()

    if ((idx + 1) % 10) == 0:
        print(f'Finished for {(idx + 1)} videos')

print(f'Finished for total {len(arr)} videos. Completed.')
# Out:
# ./dataset/processed/065kdgwe_1.MOV
# ./dataset/processed/0pfsgw9z_1.MOV
# ./dataset/processed/1nlndxyg_2.MOV
# ./dataset/processed/1qkjrxmx_1.MOV
# ./dataset/processed/1v4bggyw_2.MOV
# ./dataset/processed/27npt95d_1.MOV
# ./dataset/processed/34rd17y8_1.MOV
# ./dataset/processed/35z9bqff_3.MOV
# ./dataset/processed/3bpyl4rn_1.MOV
# ./dataset/processed/3n4kpfnk_3.MOV
# Finished for 10 videos
# ./dataset/processed/3sa851bk_2.MOV
# ./dataset/processed/3sxbzdo5_0.MOV
# ./dataset/processed/42bqlsuv_3.MOV
# ./dataset/processed/4vf5637m_2.MOV
# ./dataset/processed/4x9hsurv_1.MOV
# ./dataset/processed/51ktgnv4_2.MOV
# ./dataset/processed/52c8ry5q_0.MOV
# ./dataset/processed/5hqc7gj1_0.MOV
# ./dataset/processed/5oqq3sxx_2.MOV
# ./dataset/processed/61bfyw5j_2.MOV
# Finished for 20 videos
# ./dataset/processed/6imffdjk_1.MOV
# ./dataset/processed/73ud2nmr_1.MOV
# ./dataset/processed/87ka6p0q_2.MOV
# ./dataset/processed/8i5ntven_0.MOV
# ./dataset/processed/a37t1dqq_2.MOV
# ./dataset/processed/a7kgnkqf_0.MOV
# ./dataset/processed/aabz9a7a_3.MOV
# ./dataset/processed/afdwl1gi_3.MOV
# ./dataset/processed/aghmvdlk_1.MOV
# ./dataset/processed/an2fk0t1_2.MOV
# Finished for 30 videos
# ./dataset/processed/bbd6kbwj_0.MOV
# ./dataset/processed/c7hh65ox_1.MOV
# ./dataset/processed/cirfj60f_0.MOV
# ./dataset/processed/d5iqenml_2.MOV
# ./dataset/processed/dabw447j_0.MOV
# ./dataset/processed/dzn77ofm_3.MOV
# ./dataset/processed/e4ec5kar_3.MOV
# ./dataset/processed/f6g3b499_1.MOV
# ./dataset/processed/ffrtt1su_2.MOV
# ./dataset/processed/fmafjf5t_3.MOV
# Finished for 40 videos
# ./dataset/processed/gb5jmo9t_3.MOV
# ./dataset/processed/ge08bs2g_0.MOV
# ./dataset/processed/gok3tvt7_0.MOV
# ./dataset/processed/hkvo9l68_0.MOV
# ./dataset/processed/hm8uob9i_1.MOV
# ./dataset/processed/ig8bnk6w_3.MOV
# ./dataset/processed/jbmb88kg_0.MOV
# ./dataset/processed/jdbsmtvn_2.MOV
# ./dataset/processed/jog89l05_2.MOV
# ./dataset/processed/jssu5n4y_3.MOV
# Finished for 50 videos
# ./dataset/processed/k9n9op2v_2.MOV
# ./dataset/processed/khuxq6pp_1.MOV
# ./dataset/processed/kjkvopt0_0.MOV
# ./dataset/processed/krwrfq8m_3.MOV
# ./dataset/processed/l35smdsa_2.MOV
# ./dataset/processed/l881vgip_1.MOV
# ./dataset/processed/lepwanp5_3.MOV
# ./dataset/processed/lkvfng3n_3.MOV
# ./dataset/processed/mt3gyd7d_3.MOV
# ./dataset/processed/nkth7huj_3.MOV
# Finished for 60 videos
# ./dataset/processed/nyp3snlr_0.MOV
# ./dataset/processed/okt1gdn2_3.MOV
# ./dataset/processed/p9vuxyea_2.MOV
# ./dataset/processed/pp0y3x6y_1.MOV
# ./dataset/processed/qgq8hiwk_3.MOV
# ./dataset/processed/qmfbonj9_0.MOV
# ./dataset/processed/qtww2hem_0.MOV
# ./dataset/processed/s4pxb305_1.MOV
# ./dataset/processed/s7nzxp24_2.MOV
# ./dataset/processed/svy5ct8l_0.MOV
# Finished for 70 videos
# ./dataset/processed/syzwqd1m_2.MOV
# ./dataset/processed/tk481pwe_0.MOV
# ./dataset/processed/u12hlx03_3.MOV
# ./dataset/processed/v3vnkow7_0.MOV
# ./dataset/processed/vhznijcj_1.MOV
# ./dataset/processed/wa5qsdjj_0.MOV
# ./dataset/processed/x50u6nw7_1.MOV
# ./dataset/processed/xgygn5zm_3.MOV
# ./dataset/processed/xq8f9cmw_1.MOV
# ./dataset/processed/zin4pkdn_2.MOV
# Finished for 80 videos
# Finished for total 80 videos. Completed.

# %%
from keras.preprocessing.sequence import pad_sequences
import math


def skip_frame(landmark_npy_all, frame=50):
    new_lmk_array = []


    for each in landmark_npy_all:
        if len(each) <= frame:
        # if its less than frame, dont need to skip
            new_lmk_array.append(each)
        else:
        # skip frame by ceiling
            to_round = math.ceil(len(each)/frame)
            new_lmk_array.append(each[::to_round])
    return new_lmk_array

new_lmk_array = skip_frame(landmark_npy_all)
train_x = pad_sequences(new_lmk_array, padding='post', maxlen=50, dtype='float32')

# %%
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
classes = len(set(video_class_all))
feature_len = 20
max_len = 50

# hot encode output
train_y = to_categorical([i-1 for i in video_class_all], num_classes=classes)

print('Training y with shape of: ', train_y.shape)
print('Training x with shape of: ', train_x.shape)
X_train, X_test, y_train, y_test = train_test_split(train_x, train_y, test_size=0.2)
print("----")
print("Shape of X_train: ", X_train.shape)
print("Shape of y_train: ", y_train.shape)
print("Shape of X_test: ", X_train.shape)
print("Shape of y_test: ", y_train.shape)

#print(X_train[0][0])
# Out:
# Training y with shape of:  (80, 4)
# Training x with shape of:  (80, 50, 20)
# ----
# Shape of X_train:  (64, 50, 20)
# Shape of y_train:  (64, 4)
# Shape of X_test:  (64, 50, 20)
# Shape of y_test:  (64, 4)

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense, BatchNormalization, Activation
from keras.callbacks import LearningRateScheduler

# %%
model = Sequential()
model.add(LSTM(256, return_sequences=True, input_shape=(max_len, feature_len)))
model.add(Dropout(0.25))
model.add(LSTM(256, return_sequences=True))
model.add(Dropout(0.25))
model.add(LSTM(128, return_sequences=False))
model.add(Dense(64))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(classes, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()


def lrSchedule(epoch):
    lr = 0.001
    if epoch > 200:
        lr *= 0.0005
    elif epoch > 120:
        lr *= 0.005
    elif epoch > 50:
        lr *= 0.01
    elif epoch > 30:
        lr *= 0.1

    print('Learning rate: ', lr)
    return lr


LRScheduler = LearningRateScheduler(lrSchedule)
callbacks_list = [LRScheduler]
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 256)           283648
#
#  dropout (Dropout)           (None, 50, 256)           0
#
#  lstm_1 (LSTM)               (None, 50, 256)           525312
#
#  dropout_1 (Dropout)         (None, 50, 256)           0
#
#  lstm_2 (LSTM)               (None, 128)               197120
#
#  dense (Dense)               (None, 64)                8256
#
#  batch_normalization (Batch  (None, 64)                256
#  Normalization)
#
#  activation (Activation)     (None, 64)                0
#
#  dense_1 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 1014852 (3.87 MB)
# Trainable params: 1014724 (3.87 MB)
# Non-trainable params: 128 (512.00 Byte)
# _________________________________________________________________

# %%
verbose, epochs, batch_size = 1, 300, 8
model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs=epochs, batch_size=batch_size, verbose=verbose, shuffle=True, callbacks=callbacks_list)
# Out:
# Learning rate:  0.001
# Epoch 1/300
# 8/8 [==============================] - 7s 243ms/step - loss: 0.7305 - accuracy: 0.7500 - val_loss: 0.9745 - val_accuracy: 0.6875 - lr: 0.0010
# Learning rate:  0.001
# Epoch 2/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.5316 - accuracy: 0.8438 - val_loss: 1.2857 - val_accuracy: 0.2500 - lr: 0.0010
# Learning rate:  0.001
# Epoch 3/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.3788 - accuracy: 0.9062 - val_loss: 0.7601 - val_accuracy: 0.8125 - lr: 0.0010
# Learning rate:  0.001
# Epoch 4/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.2127 - accuracy: 0.9219 - val_loss: 0.3853 - val_accuracy: 0.9375 - lr: 0.0010
# Learning rate:  0.001
# Epoch 5/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.6933 - accuracy: 0.6875 - val_loss: 1.8186 - val_accuracy: 0.5000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 6/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.4378 - accuracy: 0.8750 - val_loss: 1.5531 - val_accuracy: 0.3125 - lr: 0.0010
# Learning rate:  0.001
# Epoch 7/300
# 8/8 [==============================] - 1s 83ms/step - loss: 0.1789 - accuracy: 0.9375 - val_loss: 1.3098 - val_accuracy: 0.2500 - lr: 0.0010
# Learning rate:  0.001
# Epoch 8/300
# 8/8 [==============================] - 1s 85ms/step - loss: 0.1726 - accuracy: 0.9531 - val_loss: 0.8605 - val_accuracy: 0.4375 - lr: 0.0010
# Learning rate:  0.001
# Epoch 9/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.1805 - accuracy: 0.9375 - val_loss: 0.9510 - val_accuracy: 0.5000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 10/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.1664 - accuracy: 0.9531 - val_loss: 0.7330 - val_accuracy: 0.6875 - lr: 0.0010
# Learning rate:  0.001
# Epoch 11/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.4011 - accuracy: 0.8281 - val_loss: 1.9224 - val_accuracy: 0.1875 - lr: 0.0010
# Learning rate:  0.001
# Epoch 12/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.1807 - accuracy: 0.9688 - val_loss: 0.6303 - val_accuracy: 0.6250 - lr: 0.0010
# Learning rate:  0.001
# Epoch 13/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.1224 - accuracy: 0.9844 - val_loss: 0.2062 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 14/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0646 - accuracy: 0.9844 - val_loss: 0.9531 - val_accuracy: 0.6250 - lr: 0.0010
# Learning rate:  0.001
# Epoch 15/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.1752 - accuracy: 0.9375 - val_loss: 0.2169 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 16/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0764 - accuracy: 0.9844 - val_loss: 0.0828 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 17/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0266 - accuracy: 1.0000 - val_loss: 0.0141 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 18/300
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 0.0125 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 19/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.3615 - val_accuracy: 0.9375 - lr: 0.0010
# Learning rate:  0.001
# Epoch 20/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0749 - accuracy: 0.9844 - val_loss: 0.0355 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 21/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.1155 - accuracy: 0.9688 - val_loss: 0.3313 - val_accuracy: 0.9375 - lr: 0.0010
# Learning rate:  0.001
# Epoch 22/300
# 8/8 [==============================] - 1s 84ms/step - loss: 0.1011 - accuracy: 0.9844 - val_loss: 0.7107 - val_accuracy: 0.6875 - lr: 0.0010
# Learning rate:  0.001
# Epoch 23/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0373 - accuracy: 1.0000 - val_loss: 0.0150 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 24/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0492 - accuracy: 0.9844 - val_loss: 0.8361 - val_accuracy: 0.6875 - lr: 0.0010
# Learning rate:  0.001
# Epoch 25/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.7280 - accuracy: 0.7812 - val_loss: 1.9132 - val_accuracy: 0.6875 - lr: 0.0010
# Learning rate:  0.001
# Epoch 26/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.2589 - accuracy: 0.9219 - val_loss: 1.0272 - val_accuracy: 0.6875 - lr: 0.0010
# Learning rate:  0.001
# Epoch 27/300
# 8/8 [==============================] - 1s 75ms/step - loss: 0.3033 - accuracy: 0.8750 - val_loss: 0.1228 - val_accuracy: 0.9375 - lr: 0.0010
# Learning rate:  0.001
# Epoch 28/300
# 8/8 [==============================] - 1s 83ms/step - loss: 0.2469 - accuracy: 0.9219 - val_loss: 0.5947 - val_accuracy: 0.6875 - lr: 0.0010
# Learning rate:  0.001
# Epoch 29/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.3972 - accuracy: 0.8906 - val_loss: 2.9276 - val_accuracy: 0.5000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 30/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.5444 - accuracy: 0.7969 - val_loss: 2.2747 - val_accuracy: 0.5000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 31/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.5591 - accuracy: 0.7344 - val_loss: 1.4418 - val_accuracy: 0.5625 - lr: 0.0010
# Learning rate:  0.0001
# Epoch 32/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.4593 - accuracy: 0.8125 - val_loss: 1.2914 - val_accuracy: 0.5625 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 33/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.3925 - accuracy: 0.8594 - val_loss: 1.3101 - val_accuracy: 0.6250 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 34/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.2598 - accuracy: 0.9375 - val_loss: 1.2620 - val_accuracy: 0.6875 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 35/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.2454 - accuracy: 0.9062 - val_loss: 1.0995 - val_accuracy: 0.6875 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 36/300
# 8/8 [==============================] - 1s 83ms/step - loss: 0.3525 - accuracy: 0.9219 - val_loss: 0.8927 - val_accuracy: 0.6875 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 37/300
# 8/8 [==============================] - 1s 85ms/step - loss: 0.2064 - accuracy: 0.9062 - val_loss: 0.8024 - val_accuracy: 0.6875 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 38/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.1278 - accuracy: 0.9844 - val_loss: 0.7961 - val_accuracy: 0.6875 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 39/300
# 8/8 [==============================] - 1s 87ms/step - loss: 0.1600 - accuracy: 0.9531 - val_loss: 0.6686 - val_accuracy: 0.6875 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 40/300
# 8/8 [==============================] - 1s 85ms/step - loss: 0.1380 - accuracy: 0.9531 - val_loss: 0.4028 - val_accuracy: 0.8750 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 41/300
# 8/8 [==============================] - 1s 92ms/step - loss: 0.1430 - accuracy: 0.9375 - val_loss: 0.6060 - val_accuracy: 0.8750 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 42/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.1253 - accuracy: 0.9688 - val_loss: 0.4944 - val_accuracy: 0.8750 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 43/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0887 - accuracy: 0.9844 - val_loss: 0.4049 - val_accuracy: 0.8750 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 44/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.0543 - accuracy: 1.0000 - val_loss: 0.3735 - val_accuracy: 0.8750 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 45/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.1114 - accuracy: 0.9531 - val_loss: 0.3629 - val_accuracy: 0.8750 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 46/300
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0382 - accuracy: 1.0000 - val_loss: 0.5858 - val_accuracy: 0.8750 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 47/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0925 - accuracy: 0.9844 - val_loss: 0.2948 - val_accuracy: 0.8750 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 48/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0461 - accuracy: 1.0000 - val_loss: 0.2584 - val_accuracy: 0.9375 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 49/300
# 8/8 [==============================] - 1s 84ms/step - loss: 0.0964 - accuracy: 1.0000 - val_loss: 0.5150 - val_accuracy: 0.8750 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 50/300
# 8/8 [==============================] - 1s 90ms/step - loss: 0.1627 - accuracy: 0.9531 - val_loss: 0.2593 - val_accuracy: 0.9375 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 51/300
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0951 - accuracy: 0.9688 - val_loss: 0.5025 - val_accuracy: 0.8750 - lr: 1.0000e-04
# Learning rate:  1e-05
# Epoch 52/300
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0901 - accuracy: 0.9844 - val_loss: 0.4641 - val_accuracy: 0.8750 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 53/300
# 8/8 [==============================] - 1s 88ms/step - loss: 0.0520 - accuracy: 0.9844 - val_loss: 0.4291 - val_accuracy: 0.8750 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 54/300
# 8/8 [==============================] - 1s 83ms/step - loss: 0.0743 - accuracy: 0.9844 - val_loss: 0.3956 - val_accuracy: 0.8750 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 55/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0325 - accuracy: 1.0000 - val_loss: 0.3588 - val_accuracy: 0.8750 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 56/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0282 - accuracy: 1.0000 - val_loss: 0.3317 - val_accuracy: 0.8750 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 57/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0505 - accuracy: 0.9844 - val_loss: 0.3146 - val_accuracy: 0.8750 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 58/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0347 - accuracy: 1.0000 - val_loss: 0.2996 - val_accuracy: 0.8750 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 59/300
# 8/8 [==============================] - 1s 83ms/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 0.2888 - val_accuracy: 0.8750 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 60/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0512 - accuracy: 1.0000 - val_loss: 0.2900 - val_accuracy: 0.8750 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 61/300
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0378 - accuracy: 1.0000 - val_loss: 0.2721 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 62/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0969 - accuracy: 0.9844 - val_loss: 0.2575 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 63/300
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0288 - accuracy: 1.0000 - val_loss: 0.2523 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 64/300
# 8/8 [==============================] - 1s 88ms/step - loss: 0.0566 - accuracy: 1.0000 - val_loss: 0.2479 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 65/300
# 8/8 [==============================] - 1s 86ms/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.2439 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 66/300
# 8/8 [==============================] - 1s 86ms/step - loss: 0.0288 - accuracy: 1.0000 - val_loss: 0.2393 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 67/300
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0663 - accuracy: 0.9844 - val_loss: 0.2392 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 68/300
# 8/8 [==============================] - 1s 92ms/step - loss: 0.0649 - accuracy: 1.0000 - val_loss: 0.2369 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 69/300
# 8/8 [==============================] - 1s 94ms/step - loss: 0.0357 - accuracy: 1.0000 - val_loss: 0.2379 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 70/300
# 8/8 [==============================] - 1s 92ms/step - loss: 0.0544 - accuracy: 1.0000 - val_loss: 0.2401 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 71/300
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.2427 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 72/300
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0424 - accuracy: 1.0000 - val_loss: 0.2443 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 73/300
# 8/8 [==============================] - 1s 99ms/step - loss: 0.0373 - accuracy: 1.0000 - val_loss: 0.2456 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 74/300
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0207 - accuracy: 1.0000 - val_loss: 0.2452 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 75/300
# 8/8 [==============================] - 1s 90ms/step - loss: 0.0360 - accuracy: 1.0000 - val_loss: 0.2454 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 76/300
# 8/8 [==============================] - 1s 90ms/step - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.2456 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 77/300
# 8/8 [==============================] - 1s 88ms/step - loss: 0.0438 - accuracy: 1.0000 - val_loss: 0.2464 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 78/300
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0348 - accuracy: 1.0000 - val_loss: 0.2497 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 79/300
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0833 - accuracy: 0.9844 - val_loss: 0.2528 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 80/300
# 8/8 [==============================] - 1s 92ms/step - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.2531 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 81/300
# 8/8 [==============================] - 1s 97ms/step - loss: 0.0801 - accuracy: 0.9688 - val_loss: 0.2631 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 82/300
# 8/8 [==============================] - 1s 94ms/step - loss: 0.0430 - accuracy: 1.0000 - val_loss: 0.2678 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 83/300
# 8/8 [==============================] - 1s 93ms/step - loss: 0.0423 - accuracy: 1.0000 - val_loss: 0.2696 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 84/300
# 8/8 [==============================] - 1s 91ms/step - loss: 0.0743 - accuracy: 1.0000 - val_loss: 0.2702 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 85/300
# 8/8 [==============================] - 1s 93ms/step - loss: 0.0269 - accuracy: 1.0000 - val_loss: 0.2706 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 86/300
# 8/8 [==============================] - 1s 87ms/step - loss: 0.0480 - accuracy: 1.0000 - val_loss: 0.2704 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 87/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0395 - accuracy: 1.0000 - val_loss: 0.2690 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 88/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0592 - accuracy: 1.0000 - val_loss: 0.2673 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 89/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0695 - accuracy: 0.9844 - val_loss: 0.2633 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 90/300
# 8/8 [==============================] - 1s 92ms/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.2590 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 91/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0298 - accuracy: 1.0000 - val_loss: 0.2568 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 92/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.2557 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 93/300
# 8/8 [==============================] - 1s 83ms/step - loss: 0.0401 - accuracy: 1.0000 - val_loss: 0.2574 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 94/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.0440 - accuracy: 1.0000 - val_loss: 0.2602 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 95/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0309 - accuracy: 1.0000 - val_loss: 0.2614 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 96/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0463 - accuracy: 1.0000 - val_loss: 0.2618 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 97/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0328 - accuracy: 1.0000 - val_loss: 0.2615 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 98/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0488 - accuracy: 1.0000 - val_loss: 0.2645 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 99/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0289 - accuracy: 1.0000 - val_loss: 0.2661 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 100/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0325 - accuracy: 1.0000 - val_loss: 0.2669 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 101/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0362 - accuracy: 1.0000 - val_loss: 0.2664 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 102/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.2657 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 103/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0659 - accuracy: 1.0000 - val_loss: 0.2623 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 104/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.0238 - accuracy: 1.0000 - val_loss: 0.2607 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 105/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0421 - accuracy: 1.0000 - val_loss: 0.2616 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 106/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0315 - accuracy: 1.0000 - val_loss: 0.2646 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 107/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.0212 - accuracy: 1.0000 - val_loss: 0.2675 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 108/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0950 - accuracy: 0.9531 - val_loss: 0.2737 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 109/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.0480 - accuracy: 1.0000 - val_loss: 0.2781 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 110/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.2793 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 111/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0592 - accuracy: 1.0000 - val_loss: 0.2805 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 112/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0448 - accuracy: 1.0000 - val_loss: 0.2809 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 113/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0416 - accuracy: 1.0000 - val_loss: 0.2777 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 114/300
# 8/8 [==============================] - 1s 83ms/step - loss: 0.0765 - accuracy: 1.0000 - val_loss: 0.2769 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 115/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0393 - accuracy: 1.0000 - val_loss: 0.2757 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 116/300
# 8/8 [==============================] - 1s 84ms/step - loss: 0.0317 - accuracy: 1.0000 - val_loss: 0.2747 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 117/300
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0303 - accuracy: 1.0000 - val_loss: 0.2755 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 118/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0183 - accuracy: 1.0000 - val_loss: 0.2764 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 119/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0264 - accuracy: 1.0000 - val_loss: 0.2784 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 120/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.2790 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 121/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0319 - accuracy: 1.0000 - val_loss: 0.2789 - val_accuracy: 0.9375 - lr: 1.0000e-05
# Learning rate:  5e-06
# Epoch 122/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0469 - accuracy: 1.0000 - val_loss: 0.2795 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 123/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0235 - accuracy: 1.0000 - val_loss: 0.2796 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 124/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.0268 - accuracy: 1.0000 - val_loss: 0.2787 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 125/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0319 - accuracy: 1.0000 - val_loss: 0.2780 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 126/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.2773 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 127/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.0634 - accuracy: 0.9844 - val_loss: 0.2769 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 128/300
# 8/8 [==============================] - 1s 87ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.2761 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 129/300
# 8/8 [==============================] - 1s 86ms/step - loss: 0.0506 - accuracy: 1.0000 - val_loss: 0.2773 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 130/300
# 8/8 [==============================] - 1s 87ms/step - loss: 0.0228 - accuracy: 1.0000 - val_loss: 0.2759 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 131/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0304 - accuracy: 1.0000 - val_loss: 0.2756 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 132/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0244 - accuracy: 1.0000 - val_loss: 0.2752 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 133/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0377 - accuracy: 1.0000 - val_loss: 0.2750 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 134/300
# 8/8 [==============================] - 1s 87ms/step - loss: 0.0391 - accuracy: 1.0000 - val_loss: 0.2753 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 135/300
# 8/8 [==============================] - 1s 84ms/step - loss: 0.0238 - accuracy: 1.0000 - val_loss: 0.2746 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 136/300
# 8/8 [==============================] - 1s 87ms/step - loss: 0.0681 - accuracy: 0.9844 - val_loss: 0.2779 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 137/300
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0647 - accuracy: 1.0000 - val_loss: 0.2806 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 138/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0246 - accuracy: 1.0000 - val_loss: 0.2798 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 139/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.2784 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 140/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0361 - accuracy: 1.0000 - val_loss: 0.2770 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 141/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0547 - accuracy: 1.0000 - val_loss: 0.2775 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 142/300
# 8/8 [==============================] - 1s 74ms/step - loss: 0.0309 - accuracy: 1.0000 - val_loss: 0.2767 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 143/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0298 - accuracy: 1.0000 - val_loss: 0.2767 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 144/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 0.2756 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 145/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0269 - accuracy: 1.0000 - val_loss: 0.2751 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 146/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0257 - accuracy: 1.0000 - val_loss: 0.2747 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 147/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0581 - accuracy: 1.0000 - val_loss: 0.2756 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 148/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0343 - accuracy: 1.0000 - val_loss: 0.2752 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 149/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0298 - accuracy: 1.0000 - val_loss: 0.2750 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 150/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0879 - accuracy: 0.9688 - val_loss: 0.2748 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 151/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0173 - accuracy: 1.0000 - val_loss: 0.2758 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 152/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0919 - accuracy: 0.9688 - val_loss: 0.2784 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 153/300
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.2789 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 154/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.2779 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 155/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0347 - accuracy: 1.0000 - val_loss: 0.2758 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 156/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0370 - accuracy: 0.9844 - val_loss: 0.2735 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 157/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0343 - accuracy: 1.0000 - val_loss: 0.2697 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 158/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0346 - accuracy: 0.9844 - val_loss: 0.2679 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 159/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0342 - accuracy: 1.0000 - val_loss: 0.2674 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 160/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.2665 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 161/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0247 - accuracy: 1.0000 - val_loss: 0.2659 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 162/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0314 - accuracy: 1.0000 - val_loss: 0.2653 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 163/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.2653 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 164/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0348 - accuracy: 1.0000 - val_loss: 0.2657 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 165/300
# 8/8 [==============================] - 1s 83ms/step - loss: 0.0288 - accuracy: 1.0000 - val_loss: 0.2665 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 166/300
# 8/8 [==============================] - 1s 84ms/step - loss: 0.0389 - accuracy: 1.0000 - val_loss: 0.2679 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 167/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.0380 - accuracy: 1.0000 - val_loss: 0.2689 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 168/300
# 8/8 [==============================] - 1s 83ms/step - loss: 0.0366 - accuracy: 1.0000 - val_loss: 0.2702 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 169/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0315 - accuracy: 1.0000 - val_loss: 0.2702 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 170/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0420 - accuracy: 1.0000 - val_loss: 0.2697 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 171/300
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0268 - accuracy: 1.0000 - val_loss: 0.2689 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 172/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0279 - accuracy: 1.0000 - val_loss: 0.2677 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 173/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.2669 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 174/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0163 - accuracy: 1.0000 - val_loss: 0.2665 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 175/300
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0257 - accuracy: 1.0000 - val_loss: 0.2653 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 176/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0264 - accuracy: 1.0000 - val_loss: 0.2630 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 177/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.2624 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 178/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0283 - accuracy: 1.0000 - val_loss: 0.2619 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 179/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0242 - accuracy: 1.0000 - val_loss: 0.2614 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 180/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.2616 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 181/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.2614 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 182/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.2607 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 183/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0235 - accuracy: 1.0000 - val_loss: 0.2603 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 184/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0516 - accuracy: 0.9844 - val_loss: 0.2598 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 185/300
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 0.2614 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 186/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0309 - accuracy: 1.0000 - val_loss: 0.2608 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 187/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0326 - accuracy: 1.0000 - val_loss: 0.2622 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 188/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0402 - accuracy: 1.0000 - val_loss: 0.2625 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 189/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0208 - accuracy: 1.0000 - val_loss: 0.2641 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 190/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.2646 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 191/300
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0362 - accuracy: 1.0000 - val_loss: 0.2657 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 192/300
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0327 - accuracy: 0.9844 - val_loss: 0.2657 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 193/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0429 - accuracy: 1.0000 - val_loss: 0.2658 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 194/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0654 - accuracy: 0.9844 - val_loss: 0.2652 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 195/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0210 - accuracy: 1.0000 - val_loss: 0.2648 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 196/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0520 - accuracy: 1.0000 - val_loss: 0.2650 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 197/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0366 - accuracy: 1.0000 - val_loss: 0.2656 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 198/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0157 - accuracy: 1.0000 - val_loss: 0.2650 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 199/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0364 - accuracy: 1.0000 - val_loss: 0.2650 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 200/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0490 - accuracy: 1.0000 - val_loss: 0.2657 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 201/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.2643 - val_accuracy: 0.9375 - lr: 5.0000e-06
# Learning rate:  5e-07
# Epoch 202/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.2642 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 203/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0325 - accuracy: 1.0000 - val_loss: 0.2643 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 204/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.1330 - accuracy: 0.9688 - val_loss: 0.2648 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 205/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0202 - accuracy: 1.0000 - val_loss: 0.2647 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 206/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.2646 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 207/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0309 - accuracy: 1.0000 - val_loss: 0.2651 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 208/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0375 - accuracy: 1.0000 - val_loss: 0.2661 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 209/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0205 - accuracy: 1.0000 - val_loss: 0.2657 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 210/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0612 - accuracy: 0.9844 - val_loss: 0.2659 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 211/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.2654 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 212/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0273 - accuracy: 1.0000 - val_loss: 0.2657 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 213/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0370 - accuracy: 1.0000 - val_loss: 0.2661 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 214/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0385 - accuracy: 1.0000 - val_loss: 0.2662 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 215/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.2659 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 216/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0313 - accuracy: 1.0000 - val_loss: 0.2655 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 217/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0353 - accuracy: 1.0000 - val_loss: 0.2656 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 218/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0315 - accuracy: 1.0000 - val_loss: 0.2652 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 219/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.2645 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 220/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0511 - accuracy: 0.9844 - val_loss: 0.2646 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 221/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0372 - accuracy: 1.0000 - val_loss: 0.2645 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 222/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.2643 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 223/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.0280 - accuracy: 1.0000 - val_loss: 0.2647 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 224/300
# 8/8 [==============================] - 1s 83ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.2644 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 225/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0287 - accuracy: 1.0000 - val_loss: 0.2639 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 226/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0327 - accuracy: 1.0000 - val_loss: 0.2644 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 227/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.2638 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 228/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.2641 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 229/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0333 - accuracy: 1.0000 - val_loss: 0.2638 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 230/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.2631 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 231/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.2627 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 232/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.2622 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 233/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.2620 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 234/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0222 - accuracy: 1.0000 - val_loss: 0.2623 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 235/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0242 - accuracy: 1.0000 - val_loss: 0.2620 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 236/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0283 - accuracy: 1.0000 - val_loss: 0.2623 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 237/300
# 8/8 [==============================] - 1s 83ms/step - loss: 0.0313 - accuracy: 1.0000 - val_loss: 0.2617 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 238/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.2612 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 239/300
# 8/8 [==============================] - 1s 83ms/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.2613 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 240/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.2609 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 241/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0438 - accuracy: 1.0000 - val_loss: 0.2607 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 242/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0729 - accuracy: 1.0000 - val_loss: 0.2609 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 243/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0218 - accuracy: 1.0000 - val_loss: 0.2608 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 244/300
# 8/8 [==============================] - 1s 83ms/step - loss: 0.0513 - accuracy: 1.0000 - val_loss: 0.2611 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 245/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0218 - accuracy: 1.0000 - val_loss: 0.2612 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 246/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.2611 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 247/300
# 8/8 [==============================] - 1s 83ms/step - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.2611 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 248/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0377 - accuracy: 1.0000 - val_loss: 0.2607 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 249/300
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0363 - accuracy: 1.0000 - val_loss: 0.2617 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 250/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0249 - accuracy: 1.0000 - val_loss: 0.2620 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 251/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0386 - accuracy: 1.0000 - val_loss: 0.2619 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 252/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0403 - accuracy: 1.0000 - val_loss: 0.2622 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 253/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0298 - accuracy: 1.0000 - val_loss: 0.2619 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 254/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0368 - accuracy: 1.0000 - val_loss: 0.2627 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 255/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0276 - accuracy: 1.0000 - val_loss: 0.2625 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 256/300
# 8/8 [==============================] - 1s 75ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.2620 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 257/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0579 - accuracy: 0.9844 - val_loss: 0.2616 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 258/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0480 - accuracy: 1.0000 - val_loss: 0.2611 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 259/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.2608 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 260/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0403 - accuracy: 1.0000 - val_loss: 0.2608 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 261/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0378 - accuracy: 1.0000 - val_loss: 0.2609 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 262/300
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.2617 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 263/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0347 - accuracy: 1.0000 - val_loss: 0.2613 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 264/300
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0245 - accuracy: 1.0000 - val_loss: 0.2611 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 265/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0719 - accuracy: 0.9844 - val_loss: 0.2618 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 266/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0432 - accuracy: 0.9844 - val_loss: 0.2612 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 267/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0671 - accuracy: 0.9844 - val_loss: 0.2611 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 268/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0348 - accuracy: 1.0000 - val_loss: 0.2602 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 269/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0355 - accuracy: 1.0000 - val_loss: 0.2592 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 270/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.0447 - accuracy: 1.0000 - val_loss: 0.2603 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 271/300
# 8/8 [==============================] - 1s 83ms/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.2599 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 272/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0234 - accuracy: 1.0000 - val_loss: 0.2605 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 273/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0547 - accuracy: 1.0000 - val_loss: 0.2611 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 274/300
# 8/8 [==============================] - 1s 84ms/step - loss: 0.0372 - accuracy: 1.0000 - val_loss: 0.2608 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 275/300
# 8/8 [==============================] - 1s 82ms/step - loss: 0.0227 - accuracy: 1.0000 - val_loss: 0.2606 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 276/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0260 - accuracy: 1.0000 - val_loss: 0.2601 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 277/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0284 - accuracy: 1.0000 - val_loss: 0.2603 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 278/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0288 - accuracy: 1.0000 - val_loss: 0.2605 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 279/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0240 - accuracy: 1.0000 - val_loss: 0.2606 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 280/300
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0236 - accuracy: 1.0000 - val_loss: 0.2605 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 281/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0242 - accuracy: 1.0000 - val_loss: 0.2598 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 282/300
# 8/8 [==============================] - 1s 83ms/step - loss: 0.0366 - accuracy: 1.0000 - val_loss: 0.2595 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 283/300
# 8/8 [==============================] - 1s 76ms/step - loss: 0.0359 - accuracy: 1.0000 - val_loss: 0.2588 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 284/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0780 - accuracy: 0.9844 - val_loss: 0.2579 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 285/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0300 - accuracy: 1.0000 - val_loss: 0.2581 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 286/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0331 - accuracy: 1.0000 - val_loss: 0.2570 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 287/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0483 - accuracy: 0.9844 - val_loss: 0.2562 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 288/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.2558 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 289/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0430 - accuracy: 1.0000 - val_loss: 0.2556 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 290/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0253 - accuracy: 1.0000 - val_loss: 0.2561 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 291/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0379 - accuracy: 1.0000 - val_loss: 0.2557 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 292/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0223 - accuracy: 1.0000 - val_loss: 0.2556 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 293/300
# 8/8 [==============================] - 1s 81ms/step - loss: 0.0263 - accuracy: 1.0000 - val_loss: 0.2553 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 294/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0233 - accuracy: 1.0000 - val_loss: 0.2549 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 295/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.1273 - accuracy: 0.9375 - val_loss: 0.2548 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 296/300
# 8/8 [==============================] - 1s 79ms/step - loss: 0.0331 - accuracy: 1.0000 - val_loss: 0.2543 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 297/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0311 - accuracy: 1.0000 - val_loss: 0.2537 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 298/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0320 - accuracy: 1.0000 - val_loss: 0.2531 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 299/300
# 8/8 [==============================] - 1s 78ms/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.2528 - val_accuracy: 0.9375 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 300/300
# 8/8 [==============================] - 1s 77ms/step - loss: 0.0345 - accuracy: 1.0000 - val_loss: 0.2525 - val_accuracy: 0.9375 - lr: 5.0000e-07

# %%
model.save("fsl-pi.h5")
# Out:
# e:\Compilers\Python\3.11.1\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from keras.models import load_model

# Replace 'your_model_path' with the actual path to your trained model
trained_model = load_model('./fsl-pi.h5')

# %%
import pandas as pd
import numpy as np
from google.protobuf.json_format import MessageToJson
# FEATURE EXTRACTOR


def distance_between(p1_loc, p2_loc):
    jsonObj = MessageToJson(results.multi_hand_landmarks[0])
    lmk = json.loads(jsonObj)['landmark']
    p1 = pd.DataFrame(lmk).to_numpy()[p1_loc]
    p2 = pd.DataFrame(lmk).to_numpy()[p2_loc]
    squared_dist = np.sum((p1-p2)**2, axis=0)
    return np.sqrt(squared_dist)


def landmark_to_dist_emb(results):
    jsonObj = MessageToJson(results.multi_hand_landmarks[0])
    lmk = json.loads(jsonObj)['landmark']

    emb = np.array([
        # thumb to finger tip
        distance_between(4, 8),
        distance_between(4, 12),
        distance_between(4, 16),
        distance_between(4, 20),
        # wrist to finger tip
        distance_between(4, 0),
        distance_between(8, 0),
        distance_between(12, 0),
        distance_between(16, 0),
        distance_between(20, 0),
        # tip to tip (specific to this application)
        distance_between(8, 12),
        distance_between(12, 16),
        # within finger joint (detect bending)
        distance_between(1, 4),
        distance_between(8, 5),
        distance_between(12, 9),
        distance_between(16, 13),
        distance_between(20, 17),
        # distance from each tip to thumb joint
        distance_between(2, 8),
        distance_between(2, 12),
        distance_between(2, 16),
        distance_between(2, 20)
    ])
    # use np normalize, as min_max may create confusion that the closest fingers has 0 distance
    emb_norm = emb / np.linalg.norm(emb)
    return emb_norm

# %%
# Create a sample input with shape (50, 20)
sample_input = np.zeros(shape=(50, 20))

# Add an extra dimension to match the model's expected input shape
sample_input = np.expand_dims(sample_input, axis=0)

# Check the shape before making predictions
print(sample_input.shape)

# Make the prediction
result = trained_model.predict(sample_input)

# Print the result
print("Prediction:", result[0][1])
# Out:
# (1, 50, 20)
# 1/1 [==============================] - 1s 1s/step
# Prediction: 0.033065025

# %%
print(np.argmax(result[0]))
# Out:
# 3

# %%
import numpy as np
import cv2
import mediapipe as mp
from google.protobuf.json_format import MessageToJson
import json

mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands
cap = cv2.VideoCapture(0)

# Use a list to store individual 1D arrays
sequential_list = []
with mp_hands.Hands(max_num_hands=2,
                    min_detection_confidence=0.5,
                    min_tracking_confidence=0.5) as hands:
    print(cap.isOpened())
    while cap.isOpened():
        success, image = cap.read()
        if not success:
            print("Ignoring empty camera frame.")

        image = cv2.cvtColor(cv2.flip(image, 1), cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        results = hands.process(image)

        # DETECT LANDMARKS
        if results.multi_hand_landmarks:
            # Append the values to the list
            sequential_list.append(landmark_to_dist_emb(results))
            #print(np.array(sequential_list).shape)

            jsonObj = MessageToJson(results.multi_hand_landmarks[0])
            lmk = json.loads(jsonObj)['landmark']
        else:
            #print("Hand Gesture Recognition Interrupted.")
            sequential_list.clear()
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                mp_drawing.draw_landmarks(
                    image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
        cv2.imshow('MediaPipe Hands', image)

        # Check if the length of the list exceeds 50
        if len(sequential_list) >= 50:
            # Convert the list to a 3D NumPy array
            sequential = np.expand_dims(np.array(sequential_list), axis=0)
            # Assuming 'predictions' is the array [8.5479594e-05, 9.9991453e-01]
            threshold = 0.5  # You can adjust this threshold based on your needs

            # Classify based on the threshold
            prediction = np.argmax(trained_model.predict(
                sequential)[0])
            if prediction == 0:
                print("Egg")
            elif prediction == 1:
                print("Chicken")
            elif prediction == 2:
                print("Crab")
            elif prediction == 3:
                print("Bread")
            # Clear the list
            sequential_list.clear()

        if cv2.waitKey(5) & 0xFF == 27:
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# True
# 1/1 [==============================] - 0s 22ms/step
# Egg
# 1/1 [==============================] - 0s 21ms/step
# Bread
# 1/1 [==============================] - 0s 20ms/step
# Crab
# 1/1 [==============================] - 0s 21ms/step
# Chicken

# %% [markdown]
# ## IMAGE DATA SCRAPING

# %%
# !pip install simple_image_download

# %%
from simple_image_download import simple_image_download as simp
response = simp.simple_image_download
keywords = ["something here", "something here"]

# keyword, n images
for kw in keywords:
    response().download(kw, 300)

# %% [markdown]
# ## LABEL DATASET

# %%
# !pip install labelImg

# %%
# !labelImg

# %% [markdown]
# ## .MOV TO IMAGES

# %%
import cv2


def convert_video_to_images(video_path, output_path, start_time_seconds=2):
    # Open the video file
    cap = cv2.VideoCapture(video_path)

    # Get the frames per second (fps) and total number of frames
    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the starting frame based on the start time
    start_frame = int(start_time_seconds * fps)

    # Set the video capture object to start from the calculated frame
    cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)

    # Loop through the frames and save them as images
    current_frame = start_frame
    while current_frame < total_frames:
        ret, frame = cap.read()
        if not ret:
            break

        # Save the frame as an image
        image_path = f"{output_path}/frame_{current_frame:04d}.png"
        cv2.imwrite(image_path, frame)

        # Increment the current frame
        current_frame += 1

    # Release the video capture object
    cap.release()


# Example usage:
video_path = 'path/to/your/video.mov'
output_path = 'path/to/output/folder'
convert_video_to_images(video_path, output_path, start_time_seconds=2)

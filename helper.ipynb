# %% [markdown]
# ## Reference

# %% [markdown]
# https://weekiat-lim.medium.com/hand-gesture-detection-sequence-recognition-7f3215f88dde

# %% [markdown]
# ## Import Libraries

# %%
"""
    Standard Python Machine Learning Libraries, for array structure and dataset loading
"""
import pandas as pd
import numpy as np


"""
    MediaPipe - used for handlandmark detection
    OpenCv - Video Image Data Extraction
    JSON | Protobuf - Data Formating
"""
import mediapipe as mp
import cv2
import json
from google.protobuf.json_format import MessageToJson


"""
    Libraries for file name processing and preparation
"""
import random
import string
import shutil
import os


"""
    Libraries to keep sequence consistency
"""
from keras.preprocessing.sequence import pad_sequences
import math

"""
    Libraries for splitting training and testing data and also transform our label classes
"""

from keras.utils import to_categorical
from sklearn.model_selection import train_test_split


"""
    Neural Network Libraries
"""

from keras.models import Sequential
from keras.layers import LSTM, Dropout, Dense, BatchNormalization, Activation
from keras.callbacks import LearningRateScheduler

# %% [markdown]
# ## Extract Features

# %%
"""
    Given the hand landmark positions transform our features so that we get distances between each hand landmark for training
"""
def distance_between(p1_loc, p2_loc):
    jsonObj = MessageToJson(results.multi_hand_landmarks[0])
    lmk = json.loads(jsonObj)['landmark']
    p1 = pd.DataFrame(lmk).to_numpy()[p1_loc]
    p2 = pd.DataFrame(lmk).to_numpy()[p2_loc]
    squared_dist = np.sum((p1-p2)**2, axis=0)
    return np.sqrt(squared_dist)

"""
    Utility function to calculate the distance between each hand landmark
"""
def landmark_to_dist_emb(results):
    jsonObj = MessageToJson(results.multi_hand_landmarks[0])
    lmk = json.loads(jsonObj)['landmark']

    emb = np.array([
        # thumb to finger tip
        distance_between(4, 8),
        distance_between(4, 12),
        distance_between(4, 16),
        distance_between(4, 20),
        # wrist to finger tip
        distance_between(4, 0),
        distance_between(8, 0),
        distance_between(12, 0),
        distance_between(16, 0),
        distance_between(20, 0),
        # tip to tip (specific to this application)
        distance_between(8, 12),
        distance_between(12, 16),
        # within finger joint (detect bending)
        distance_between(1, 4),
        distance_between(8, 5),
        distance_between(12, 9),
        distance_between(16, 13),
        distance_between(20, 17),
        # distance from each tip to thumb joint
        distance_between(2, 8),
        distance_between(2, 12),
        distance_between(2, 16),
        distance_between(2, 20)
    ])

    emb_norm = emb / np.linalg.norm(emb)
    return emb_norm

# %% [markdown]
# ####

# %% [markdown]
# ## Visualize and Test Hand Landmark Traking for MediaPipe using OpenCV

# %%
"""
    MediaPipe has many utility features, this will help us utilize the hand landmark detection.
"""
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# %%
"""
  For testing purposes, Utilize OpenCV to display Hand Landmark recognition done by MediaPipe
"""

with mp_hands.Hands(max_num_hands=2,
                    min_detection_confidence=0.5,
                    min_tracking_confidence=0.5) as hands:
  while cap.isOpened():
    success, image = cap.read()
    if not success:
      print("Ignoring empty camera frame.")

    image = cv2.cvtColor(cv2.flip(image, 1), cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = hands.process(image)

    # DETECT LANDMARKS
    if results.multi_hand_landmarks:

      #print(landmark_to_dist_emb(results).shape) process input
      jsonObj = MessageToJson(results.multi_hand_landmarks[0])
      lmk = json.loads(jsonObj)['landmark']
      
      #print(len(lmk))  # lmk = hand's landmark

# Draw the hand annotations on the image.
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    if results.multi_hand_landmarks:
      for hand_landmarks in results.multi_hand_landmarks:
        mp_drawing.draw_landmarks(
            image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
    cv2.imshow('MediaPipe Hands', image)
    if cv2.waitKey(5) & 0xFF == 27:
      break
cap.release()

# %%
"""
    Utility Function for UID generation and renaming of files
"""

def generate_random_uid():
    """Generate a random UID."""
    return ''.join(random.choices(string.ascii_lowercase + string.digits, k=8))



"""
    Remake files for class labeling
"""
def rename_videos(source_directory, destination_directory, idx):
    """Rename videos in the specified directory."""
    for root, dirs, files in os.walk(source_directory):
        for file in files:
            if file.endswith(".MOV"):
                old_path = os.path.join(root, file)
                new_uid = generate_random_uid()
                new_name = f"{new_uid}_{idx}.MOV"
                new_path = os.path.join(destination_directory, new_name)

                shutil.copy(old_path, new_path)
                print(f"Renamed and copied: {old_path} to {new_path}")

""" 
    Update Target Classes Filenames and move them to a single directory for dataset processing
"""
# Specify the source directory containing the videos
source_directory = './dataset/clips/'

# Specify the destination directory for the renamed videos
destination_directory = './dataset/processed/'

# Create the destination directory if it doesn't exist
os.makedirs(destination_directory, exist_ok=True)

# Call the function to rename and copy the videos
targetSets = [85, 86, 89, 94]

for idx, target in enumerate(targetSets):
    print("Renaming Target Set: ", target)
    rename_videos(source_directory + str(target), destination_directory, idx)
    print("\n\n")
# Out:
# Renaming Target Set:  85
# Renamed and copied: ./dataset/clips/85\11taoceh_0.MOV to ./dataset/processed/kjkvopt0_0.MOV
# Renamed and copied: ./dataset/clips/85\4asdlwz1_0.MOV to ./dataset/processed/qtww2hem_0.MOV
# Renamed and copied: ./dataset/clips/85\4wjsa5wq_0.MOV to ./dataset/processed/8i5ntven_0.MOV
# Renamed and copied: ./dataset/clips/85\940bqr4z_0.MOV to ./dataset/processed/qmfbonj9_0.MOV
# Renamed and copied: ./dataset/clips/85\9dppbec3_0.MOV to ./dataset/processed/a7kgnkqf_0.MOV
# Renamed and copied: ./dataset/clips/85\f9r9bsva_0.MOV to ./dataset/processed/nyp3snlr_0.MOV
# Renamed and copied: ./dataset/clips/85\fdpnld0t_0.MOV to ./dataset/processed/bbd6kbwj_0.MOV
# Renamed and copied: ./dataset/clips/85\fx5jgfby_0.MOV to ./dataset/processed/5hqc7gj1_0.MOV
# Renamed and copied: ./dataset/clips/85\gwa534to_0.MOV to ./dataset/processed/v3vnkow7_0.MOV
# Renamed and copied: ./dataset/clips/85\i6641z1q_0.MOV to ./dataset/processed/hkvo9l68_0.MOV
# Renamed and copied: ./dataset/clips/85\inl5n07c_0.MOV to ./dataset/processed/wa5qsdjj_0.MOV
# Renamed and copied: ./dataset/clips/85\mato6gvs_0.MOV to ./dataset/processed/dabw447j_0.MOV
# Renamed and copied: ./dataset/clips/85\nz7q913t_0.MOV to ./dataset/processed/tk481pwe_0.MOV
# Renamed and copied: ./dataset/clips/85\opunh4zs_0.MOV to ./dataset/processed/jbmb88kg_0.MOV
# Renamed and copied: ./dataset/clips/85\p5ga19wa_0.MOV to ./dataset/processed/ge08bs2g_0.MOV
# Renamed and copied: ./dataset/clips/85\qygo7g5s_0.MOV to ./dataset/processed/svy5ct8l_0.MOV
# Renamed and copied: ./dataset/clips/85\r4znhltx_0.MOV to ./dataset/processed/gok3tvt7_0.MOV
# Renamed and copied: ./dataset/clips/85\titl2dvs_0.MOV to ./dataset/processed/3sxbzdo5_0.MOV
# Renamed and copied: ./dataset/clips/85\tzd3o8eu_0.MOV to ./dataset/processed/52c8ry5q_0.MOV
# Renamed and copied: ./dataset/clips/85\vvzajti5_0.MOV to ./dataset/processed/cirfj60f_0.MOV
#
#
#
# Renaming Target Set:  86
# Renamed and copied: ./dataset/clips/86\0.MOV to ./dataset/processed/f6g3b499_1.MOV
# Renamed and copied: ./dataset/clips/86\1.MOV to ./dataset/processed/khuxq6pp_1.MOV
# Renamed and copied: ./dataset/clips/86\10.MOV to ./dataset/processed/3bpyl4rn_1.MOV
# Renamed and copied: ./dataset/clips/86\11.MOV to ./dataset/processed/pp0y3x6y_1.MOV
# Renamed and copied: ./dataset/clips/86\12.MOV to ./dataset/processed/c7hh65ox_1.MOV
# Renamed and copied: ./dataset/clips/86\13.MOV to ./dataset/processed/6imffdjk_1.MOV
# Renamed and copied: ./dataset/clips/86\14.MOV to ./dataset/processed/s4pxb305_1.MOV
# Renamed and copied: ./dataset/clips/86\15.MOV to ./dataset/processed/34rd17y8_1.MOV
# Renamed and copied: ./dataset/clips/86\16.MOV to ./dataset/processed/x50u6nw7_1.MOV
# Renamed and copied: ./dataset/clips/86\17.MOV to ./dataset/processed/vhznijcj_1.MOV
# Renamed and copied: ./dataset/clips/86\18.MOV to ./dataset/processed/27npt95d_1.MOV
# Renamed and copied: ./dataset/clips/86\19.MOV to ./dataset/processed/hm8uob9i_1.MOV
# Renamed and copied: ./dataset/clips/86\2.MOV to ./dataset/processed/73ud2nmr_1.MOV
# Renamed and copied: ./dataset/clips/86\3.MOV to ./dataset/processed/l881vgip_1.MOV
# Renamed and copied: ./dataset/clips/86\4.MOV to ./dataset/processed/0pfsgw9z_1.MOV
# Renamed and copied: ./dataset/clips/86\5.MOV to ./dataset/processed/xq8f9cmw_1.MOV
# Renamed and copied: ./dataset/clips/86\6.MOV to ./dataset/processed/aghmvdlk_1.MOV
# Renamed and copied: ./dataset/clips/86\7.MOV to ./dataset/processed/1qkjrxmx_1.MOV
# Renamed and copied: ./dataset/clips/86\8.MOV to ./dataset/processed/065kdgwe_1.MOV
# Renamed and copied: ./dataset/clips/86\9.MOV to ./dataset/processed/4x9hsurv_1.MOV
#
#
#
# Renaming Target Set:  89
# Renamed and copied: ./dataset/clips/89\0.MOV to ./dataset/processed/5oqq3sxx_2.MOV
# Renamed and copied: ./dataset/clips/89\1.MOV to ./dataset/processed/1nlndxyg_2.MOV
# Renamed and copied: ./dataset/clips/89\10.MOV to ./dataset/processed/syzwqd1m_2.MOV
# Renamed and copied: ./dataset/clips/89\11.MOV to ./dataset/processed/an2fk0t1_2.MOV
# Renamed and copied: ./dataset/clips/89\12.MOV to ./dataset/processed/61bfyw5j_2.MOV
# Renamed and copied: ./dataset/clips/89\13.MOV to ./dataset/processed/51ktgnv4_2.MOV
# Renamed and copied: ./dataset/clips/89\14.MOV to ./dataset/processed/d5iqenml_2.MOV
# Renamed and copied: ./dataset/clips/89\15.MOV to ./dataset/processed/s7nzxp24_2.MOV
# Renamed and copied: ./dataset/clips/89\16.MOV to ./dataset/processed/ffrtt1su_2.MOV
# Renamed and copied: ./dataset/clips/89\17.MOV to ./dataset/processed/l35smdsa_2.MOV
# Renamed and copied: ./dataset/clips/89\18.MOV to ./dataset/processed/a37t1dqq_2.MOV
# Renamed and copied: ./dataset/clips/89\19.MOV to ./dataset/processed/1v4bggyw_2.MOV
# Renamed and copied: ./dataset/clips/89\2.MOV to ./dataset/processed/k9n9op2v_2.MOV
# Renamed and copied: ./dataset/clips/89\3.MOV to ./dataset/processed/jdbsmtvn_2.MOV
# Renamed and copied: ./dataset/clips/89\4.MOV to ./dataset/processed/jog89l05_2.MOV
# Renamed and copied: ./dataset/clips/89\5.MOV to ./dataset/processed/3sa851bk_2.MOV
# Renamed and copied: ./dataset/clips/89\6.MOV to ./dataset/processed/zin4pkdn_2.MOV
# Renamed and copied: ./dataset/clips/89\7.MOV to ./dataset/processed/87ka6p0q_2.MOV
# Renamed and copied: ./dataset/clips/89\8.MOV to ./dataset/processed/4vf5637m_2.MOV
# Renamed and copied: ./dataset/clips/89\9.MOV to ./dataset/processed/p9vuxyea_2.MOV
#
#
#
# Renaming Target Set:  94
# Renamed and copied: ./dataset/clips/94\0.MOV to ./dataset/processed/35z9bqff_3.MOV
# Renamed and copied: ./dataset/clips/94\1.MOV to ./dataset/processed/gb5jmo9t_3.MOV
# Renamed and copied: ./dataset/clips/94\10.MOV to ./dataset/processed/fmafjf5t_3.MOV
# Renamed and copied: ./dataset/clips/94\11.MOV to ./dataset/processed/lkvfng3n_3.MOV
# Renamed and copied: ./dataset/clips/94\12.MOV to ./dataset/processed/ig8bnk6w_3.MOV
# Renamed and copied: ./dataset/clips/94\13.MOV to ./dataset/processed/nkth7huj_3.MOV
# Renamed and copied: ./dataset/clips/94\14.MOV to ./dataset/processed/dzn77ofm_3.MOV
# Renamed and copied: ./dataset/clips/94\15.MOV to ./dataset/processed/okt1gdn2_3.MOV
# Renamed and copied: ./dataset/clips/94\16.MOV to ./dataset/processed/3n4kpfnk_3.MOV
# Renamed and copied: ./dataset/clips/94\17.MOV to ./dataset/processed/krwrfq8m_3.MOV
# Renamed and copied: ./dataset/clips/94\18.MOV to ./dataset/processed/xgygn5zm_3.MOV
# Renamed and copied: ./dataset/clips/94\19.MOV to ./dataset/processed/lepwanp5_3.MOV
# Renamed and copied: ./dataset/clips/94\2.MOV to ./dataset/processed/afdwl1gi_3.MOV
# Renamed and copied: ./dataset/clips/94\3.MOV to ./dataset/processed/qgq8hiwk_3.MOV
# Renamed and copied: ./dataset/clips/94\4.MOV to ./dataset/processed/jssu5n4y_3.MOV
# Renamed and copied: ./dataset/clips/94\5.MOV to ./dataset/processed/mt3gyd7d_3.MOV
# Renamed and copied: ./dataset/clips/94\6.MOV to ./dataset/processed/42bqlsuv_3.MOV
# Renamed and copied: ./dataset/clips/94\7.MOV to ./dataset/processed/e4ec5kar_3.MOV
# Renamed and copied: ./dataset/clips/94\8.MOV to ./dataset/processed/aabz9a7a_3.MOV
# Renamed and copied: ./dataset/clips/94\9.MOV to ./dataset/processed/u12hlx03_3.MOV

# %% [markdown]
# ## Feature Extraction & Processing

# %%
"""
    Given all video data, analyze it using OpenCV and detect hand landmarks on the video, afterwards extraft important features such as distances between each segment.
"""

arr = os.listdir('./dataset/processed')
video_class_all = []
landmark_npy_all = []
handnn = mp.solutions.hands.Hands(
    max_num_hands=2, min_detection_confidence=0.6, min_tracking_confidence=0.6)

for idx, eachVideo in enumerate(arr):
    landmark_npy_single = []  # Reset for each video
    video = './dataset/processed/' + eachVideo
    cap = cv2.VideoCapture(video)
    video_class_all.append(int(video.split('_')[1].split('.')[0]))
    print(video)
    while cap.isOpened():
        success, image = cap.read()
        if not success:
            break

        image = cv2.cvtColor(cv2.flip(image, 1), cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        results = handnn.process(image)
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                landmark_npy_single.append(landmark_to_dist_emb(results))

    # Append landmarks for each video only once
    landmark_npy_all.append(landmark_npy_single)

    cap.release()

    if ((idx + 1) % 10) == 0:
        print(f'Finished for {(idx + 1)} videos')

print(f'Finished for total {len(arr)} videos. Completed.')
# Out:
# ./dataset/processed/065kdgwe_1.MOV
# ./dataset/processed/0pfsgw9z_1.MOV
# ./dataset/processed/1nlndxyg_2.MOV
# ./dataset/processed/1qkjrxmx_1.MOV
# ./dataset/processed/1v4bggyw_2.MOV
# ./dataset/processed/27npt95d_1.MOV
# ./dataset/processed/34rd17y8_1.MOV
# ./dataset/processed/35z9bqff_3.MOV
# ./dataset/processed/3bpyl4rn_1.MOV
# ./dataset/processed/3n4kpfnk_3.MOV
# Finished for 10 videos
# ./dataset/processed/3sa851bk_2.MOV
# ./dataset/processed/3sxbzdo5_0.MOV
# ./dataset/processed/42bqlsuv_3.MOV
# ./dataset/processed/4vf5637m_2.MOV
# ./dataset/processed/4x9hsurv_1.MOV
# ./dataset/processed/51ktgnv4_2.MOV
# ./dataset/processed/52c8ry5q_0.MOV
# ./dataset/processed/5hqc7gj1_0.MOV
# ./dataset/processed/5oqq3sxx_2.MOV
# ./dataset/processed/61bfyw5j_2.MOV
# Finished for 20 videos
# ./dataset/processed/6imffdjk_1.MOV
# ./dataset/processed/73ud2nmr_1.MOV
# ./dataset/processed/87ka6p0q_2.MOV
# ./dataset/processed/8i5ntven_0.MOV
# ./dataset/processed/a37t1dqq_2.MOV
# ./dataset/processed/a7kgnkqf_0.MOV
# ./dataset/processed/aabz9a7a_3.MOV
# ./dataset/processed/afdwl1gi_3.MOV
# ./dataset/processed/aghmvdlk_1.MOV
# ./dataset/processed/an2fk0t1_2.MOV
# Finished for 30 videos
# ./dataset/processed/bbd6kbwj_0.MOV
# ./dataset/processed/c7hh65ox_1.MOV
# ./dataset/processed/cirfj60f_0.MOV
# ./dataset/processed/d5iqenml_2.MOV
# ./dataset/processed/dabw447j_0.MOV
# ./dataset/processed/dzn77ofm_3.MOV
# ./dataset/processed/e4ec5kar_3.MOV
# ./dataset/processed/f6g3b499_1.MOV
# ./dataset/processed/ffrtt1su_2.MOV
# ./dataset/processed/fmafjf5t_3.MOV
# Finished for 40 videos
# ./dataset/processed/gb5jmo9t_3.MOV
# ./dataset/processed/ge08bs2g_0.MOV
# ./dataset/processed/gok3tvt7_0.MOV
# ./dataset/processed/hkvo9l68_0.MOV
# ./dataset/processed/hm8uob9i_1.MOV
# ./dataset/processed/ig8bnk6w_3.MOV
# ./dataset/processed/jbmb88kg_0.MOV
# ./dataset/processed/jdbsmtvn_2.MOV
# ./dataset/processed/jog89l05_2.MOV
# ./dataset/processed/jssu5n4y_3.MOV
# Finished for 50 videos
# ./dataset/processed/k9n9op2v_2.MOV
# ./dataset/processed/khuxq6pp_1.MOV
# ./dataset/processed/kjkvopt0_0.MOV
# ./dataset/processed/krwrfq8m_3.MOV
# ./dataset/processed/l35smdsa_2.MOV
# ./dataset/processed/l881vgip_1.MOV
# ./dataset/processed/lepwanp5_3.MOV
# ./dataset/processed/lkvfng3n_3.MOV
# ./dataset/processed/mt3gyd7d_3.MOV
# ./dataset/processed/nkth7huj_3.MOV
# Finished for 60 videos
# ./dataset/processed/nyp3snlr_0.MOV
# ./dataset/processed/okt1gdn2_3.MOV
# ./dataset/processed/p9vuxyea_2.MOV
# ./dataset/processed/pp0y3x6y_1.MOV
# ./dataset/processed/qgq8hiwk_3.MOV
# ./dataset/processed/qmfbonj9_0.MOV
# ./dataset/processed/qtww2hem_0.MOV
# ./dataset/processed/s4pxb305_1.MOV
# ./dataset/processed/s7nzxp24_2.MOV
# ./dataset/processed/svy5ct8l_0.MOV
# Finished for 70 videos
# ./dataset/processed/syzwqd1m_2.MOV
# ./dataset/processed/tk481pwe_0.MOV
# ./dataset/processed/u12hlx03_3.MOV
# ./dataset/processed/v3vnkow7_0.MOV
# ./dataset/processed/vhznijcj_1.MOV
# ./dataset/processed/wa5qsdjj_0.MOV
# ./dataset/processed/x50u6nw7_1.MOV
# ./dataset/processed/xgygn5zm_3.MOV
# ./dataset/processed/xq8f9cmw_1.MOV
# ./dataset/processed/zin4pkdn_2.MOV
# Finished for 80 videos
# Finished for total 80 videos. Completed.

# %% [markdown]
# ## Make sure Data Sequence is consistent

# %%
def skip_frame(landmark_npy_all, frame=50):
    new_lmk_array = []


    for each in landmark_npy_all:
        if len(each) <= frame:
        # if its less than frame, dont need to skip
            new_lmk_array.append(each)
        else:
        # skip frame by ceiling
            to_round = math.ceil(len(each)/frame)
            new_lmk_array.append(each[::to_round])
    return new_lmk_array

new_lmk_array = skip_frame(landmark_npy_all)
train_x = pad_sequences(new_lmk_array, padding='post', maxlen=10, dtype='float32')

# %% [markdown]
# ## Prepare Training and Testing Data

# %%
classes = len(set(video_class_all))
feature_len = 20
max_len = 10

# hot encode output
train_y = to_categorical([i-1 for i in video_class_all], num_classes=classes)

print('Training y with shape of: ', train_y.shape)
print('Training x with shape of: ', train_x.shape)
X_train, X_test, y_train, y_test = train_test_split(train_x, train_y, test_size=0.2)
print("----")
print("Shape of X_train: ", X_train.shape)
print("Shape of y_train: ", y_train.shape)
print("Shape of X_test: ", X_train.shape)
print("Shape of y_test: ", y_train.shape)
# Out:
# Training y with shape of:  (80, 4)
# Training x with shape of:  (80, 10, 20)
# ----
# Shape of X_train:  (64, 10, 20)
# Shape of y_train:  (64, 4)
# Shape of X_test:  (64, 10, 20)
# Shape of y_test:  (64, 4)

# %% [markdown]
# ## Build Model Architecture

# %%
model = Sequential()
model.add(LSTM(256, return_sequences=True, input_shape=(max_len, feature_len)))
model.add(Dropout(0.25))
model.add(LSTM(256, return_sequences=True))
model.add(Dropout(0.25))
model.add(LSTM(128, return_sequences=False))
model.add(Dense(64))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(classes, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()


def lrSchedule(epoch):
    lr = 0.001
    if epoch > 200:
        lr *= 0.0005
    elif epoch > 120:
        lr *= 0.005
    elif epoch > 50:
        lr *= 0.01
    elif epoch > 30:
        lr *= 0.1

    print('Learning rate: ', lr)
    return lr


LRScheduler = LearningRateScheduler(lrSchedule)
callbacks_list = [LRScheduler]
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 10, 256)           283648
#
#  dropout_2 (Dropout)         (None, 10, 256)           0
#
#  lstm_4 (LSTM)               (None, 10, 256)           525312
#
#  dropout_3 (Dropout)         (None, 10, 256)           0
#
#  lstm_5 (LSTM)               (None, 128)               197120
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  batch_normalization_1 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_1 (Activation)   (None, 64)                0
#
#  dense_3 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 1014852 (3.87 MB)
# Trainable params: 1014724 (3.87 MB)
# Non-trainable params: 128 (512.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## Train Model

# %%
verbose, epochs, batch_size = 1, 300, 8
model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs=epochs, batch_size=batch_size, verbose=verbose, shuffle=True, callbacks=callbacks_list)
# Out:
# Learning rate:  0.001
# Epoch 1/300
# WARNING:tensorflow:From e:\Compilers\Python\3.11.1\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From e:\Compilers\Python\3.11.1\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
# WARNING:tensorflow:From e:\Compilers\Python\3.11.1\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:tensorflow:From e:\Compilers\Python\3.11.1\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# 8/8 [==============================] - 7s 211ms/step - loss: 0.9773 - accuracy: 0.6562 - val_loss: 1.3223 - val_accuracy: 0.4375 - lr: 0.0010
# Learning rate:  0.001
# Epoch 2/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4806 - accuracy: 0.8125 - val_loss: 1.1398 - val_accuracy: 0.6250 - lr: 0.0010
# Learning rate:  0.001
# Epoch 3/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2679 - accuracy: 0.9531 - val_loss: 1.1162 - val_accuracy: 0.5625 - lr: 0.0010
# Learning rate:  0.001
# Epoch 4/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2191 - accuracy: 0.9531 - val_loss: 0.9171 - val_accuracy: 0.9375 - lr: 0.0010
# Learning rate:  0.001
# Epoch 5/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2309 - accuracy: 0.9219 - val_loss: 0.5785 - val_accuracy: 0.9375 - lr: 0.0010
# Learning rate:  0.001
# Epoch 6/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4878 - accuracy: 0.8594 - val_loss: 0.6502 - val_accuracy: 0.9375 - lr: 0.0010
# Learning rate:  0.001
# Epoch 7/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4121 - accuracy: 0.8750 - val_loss: 1.3735 - val_accuracy: 0.2500 - lr: 0.0010
# Learning rate:  0.001
# Epoch 8/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4016 - accuracy: 0.8750 - val_loss: 1.2001 - val_accuracy: 0.2500 - lr: 0.0010
# Learning rate:  0.001
# Epoch 9/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.4427 - accuracy: 0.8750 - val_loss: 0.7806 - val_accuracy: 0.8125 - lr: 0.0010
# Learning rate:  0.001
# Epoch 10/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2294 - accuracy: 0.9062 - val_loss: 0.6913 - val_accuracy: 0.8750 - lr: 0.0010
# Learning rate:  0.001
# Epoch 11/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1680 - accuracy: 0.9531 - val_loss: 0.6298 - val_accuracy: 0.9375 - lr: 0.0010
# Learning rate:  0.001
# Epoch 12/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2228 - accuracy: 0.9375 - val_loss: 0.6759 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 13/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1568 - accuracy: 0.9531 - val_loss: 0.6961 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 14/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0804 - accuracy: 0.9844 - val_loss: 0.5144 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 15/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1753 - accuracy: 0.9531 - val_loss: 0.4572 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 16/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2070 - accuracy: 0.9375 - val_loss: 0.7013 - val_accuracy: 0.7500 - lr: 0.0010
# Learning rate:  0.001
# Epoch 17/300
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1595 - accuracy: 0.9531 - val_loss: 0.7288 - val_accuracy: 0.7500 - lr: 0.0010
# Learning rate:  0.001
# Epoch 18/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1229 - accuracy: 0.9844 - val_loss: 0.9053 - val_accuracy: 0.3125 - lr: 0.0010
# Learning rate:  0.001
# Epoch 19/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1551 - accuracy: 0.9688 - val_loss: 0.5798 - val_accuracy: 0.8750 - lr: 0.0010
# Learning rate:  0.001
# Epoch 20/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1333 - accuracy: 0.9688 - val_loss: 0.5724 - val_accuracy: 0.8750 - lr: 0.0010
# Learning rate:  0.001
# Epoch 21/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0920 - accuracy: 0.9844 - val_loss: 0.3042 - val_accuracy: 0.9375 - lr: 0.0010
# Learning rate:  0.001
# Epoch 22/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1236 - accuracy: 0.9844 - val_loss: 0.2054 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 23/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1547 - accuracy: 0.9375 - val_loss: 0.1799 - val_accuracy: 1.0000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 24/300
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1195 - accuracy: 0.9688 - val_loss: 1.3257 - val_accuracy: 0.5000 - lr: 0.0010
# Learning rate:  0.001
# Epoch 25/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0822 - accuracy: 0.9688 - val_loss: 0.8392 - val_accuracy: 0.5625 - lr: 0.0010
# Learning rate:  0.001
# Epoch 26/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0881 - accuracy: 0.9844 - val_loss: 0.7208 - val_accuracy: 0.7500 - lr: 0.0010
# Learning rate:  0.001
# Epoch 27/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1700 - accuracy: 0.9688 - val_loss: 0.9056 - val_accuracy: 0.6875 - lr: 0.0010
# Learning rate:  0.001
# Epoch 28/300
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1115 - accuracy: 0.9688 - val_loss: 0.8776 - val_accuracy: 0.6250 - lr: 0.0010
# Learning rate:  0.001
# Epoch 29/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0600 - accuracy: 0.9844 - val_loss: 0.2857 - val_accuracy: 0.8750 - lr: 0.0010
# Learning rate:  0.001
# Epoch 30/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0873 - accuracy: 0.9688 - val_loss: 0.2965 - val_accuracy: 0.9375 - lr: 0.0010
# Learning rate:  0.001
# Epoch 31/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1452 - accuracy: 0.9531 - val_loss: 0.2621 - val_accuracy: 0.9375 - lr: 0.0010
# Learning rate:  0.0001
# Epoch 32/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1472 - accuracy: 0.9531 - val_loss: 0.2035 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 33/300
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1560 - accuracy: 0.9531 - val_loss: 0.0767 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 34/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0740 - accuracy: 1.0000 - val_loss: 0.0509 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 35/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0572 - accuracy: 0.9844 - val_loss: 0.0446 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 36/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0648 - accuracy: 0.9844 - val_loss: 0.0384 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 37/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0605 - accuracy: 0.9844 - val_loss: 0.0323 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 38/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0727 - accuracy: 0.9844 - val_loss: 0.0341 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 39/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0655 - accuracy: 1.0000 - val_loss: 0.0297 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 40/300
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0526 - accuracy: 0.9844 - val_loss: 0.0274 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 41/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0398 - accuracy: 0.9844 - val_loss: 0.0273 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 42/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0563 - accuracy: 0.9844 - val_loss: 0.0276 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 43/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0536 - accuracy: 0.9844 - val_loss: 0.0252 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 44/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0484 - accuracy: 0.9844 - val_loss: 0.0245 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 45/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0496 - accuracy: 1.0000 - val_loss: 0.0233 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 46/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0681 - accuracy: 0.9844 - val_loss: 0.0215 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 47/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1231 - accuracy: 0.9688 - val_loss: 0.0233 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 48/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1306 - accuracy: 0.9844 - val_loss: 0.0281 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 49/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0443 - accuracy: 0.9844 - val_loss: 0.0324 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 50/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1289 - accuracy: 0.9375 - val_loss: 0.0421 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  0.0001
# Epoch 51/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1201 - accuracy: 0.9688 - val_loss: 0.0938 - val_accuracy: 1.0000 - lr: 1.0000e-04
# Learning rate:  1e-05
# Epoch 52/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0795 - accuracy: 0.9688 - val_loss: 0.0824 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 53/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0645 - accuracy: 0.9844 - val_loss: 0.0688 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 54/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0351 - accuracy: 0.9844 - val_loss: 0.0568 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 55/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0705 - accuracy: 0.9844 - val_loss: 0.0467 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 56/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0443 - accuracy: 0.9844 - val_loss: 0.0391 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 57/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0506 - accuracy: 0.9844 - val_loss: 0.0335 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 58/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0743 - accuracy: 0.9688 - val_loss: 0.0288 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 59/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0826 - accuracy: 0.9844 - val_loss: 0.0251 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 60/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1445 - accuracy: 0.9531 - val_loss: 0.0222 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 61/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0399 - accuracy: 0.9844 - val_loss: 0.0197 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 62/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0465 - accuracy: 0.9844 - val_loss: 0.0180 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 63/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0377 - accuracy: 0.9844 - val_loss: 0.0167 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 64/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0433 - accuracy: 0.9844 - val_loss: 0.0155 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 65/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0590 - accuracy: 0.9844 - val_loss: 0.0144 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 66/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0653 - accuracy: 0.9844 - val_loss: 0.0131 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 67/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0542 - accuracy: 1.0000 - val_loss: 0.0124 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 68/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0327 - accuracy: 1.0000 - val_loss: 0.0121 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 69/300
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0834 - accuracy: 0.9844 - val_loss: 0.0116 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 70/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0623 - accuracy: 0.9844 - val_loss: 0.0114 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 71/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0328 - accuracy: 0.9844 - val_loss: 0.0112 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 72/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0785 - accuracy: 0.9688 - val_loss: 0.0109 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 73/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0439 - accuracy: 0.9844 - val_loss: 0.0107 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 74/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0662 - accuracy: 0.9844 - val_loss: 0.0104 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 75/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0483 - accuracy: 0.9844 - val_loss: 0.0102 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 76/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1522 - accuracy: 0.9531 - val_loss: 0.0100 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 77/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2045 - accuracy: 0.9688 - val_loss: 0.0103 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 78/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0639 - accuracy: 0.9844 - val_loss: 0.0102 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 79/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0500 - accuracy: 0.9844 - val_loss: 0.0102 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 80/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0515 - accuracy: 0.9844 - val_loss: 0.0101 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 81/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1479 - accuracy: 0.9531 - val_loss: 0.0108 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 82/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0506 - accuracy: 0.9844 - val_loss: 0.0116 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 83/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0551 - accuracy: 0.9844 - val_loss: 0.0122 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 84/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0532 - accuracy: 0.9844 - val_loss: 0.0123 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 85/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1294 - accuracy: 0.9531 - val_loss: 0.0133 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 86/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0535 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 87/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1294 - accuracy: 0.9844 - val_loss: 0.0133 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 88/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0759 - accuracy: 0.9844 - val_loss: 0.0122 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 89/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1717 - accuracy: 0.9688 - val_loss: 0.0105 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 90/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0538 - accuracy: 0.9844 - val_loss: 0.0097 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 91/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0494 - accuracy: 0.9844 - val_loss: 0.0091 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 92/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1153 - accuracy: 0.9688 - val_loss: 0.0086 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 93/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0623 - accuracy: 0.9844 - val_loss: 0.0082 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 94/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1205 - accuracy: 0.9531 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 95/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0778 - accuracy: 0.9844 - val_loss: 0.0074 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 96/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0433 - accuracy: 0.9844 - val_loss: 0.0071 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 97/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0541 - accuracy: 0.9844 - val_loss: 0.0069 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 98/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0415 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 99/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0577 - accuracy: 0.9844 - val_loss: 0.0072 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 100/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0352 - accuracy: 1.0000 - val_loss: 0.0075 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 101/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0621 - accuracy: 0.9844 - val_loss: 0.0077 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 102/300
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0657 - accuracy: 0.9844 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 103/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0611 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 104/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0778 - accuracy: 0.9844 - val_loss: 0.0082 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 105/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2021 - accuracy: 0.9531 - val_loss: 0.0081 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 106/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0366 - accuracy: 0.9844 - val_loss: 0.0081 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 107/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0546 - accuracy: 0.9844 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 108/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1118 - accuracy: 0.9688 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 109/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0599 - accuracy: 0.9844 - val_loss: 0.0077 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 110/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0361 - accuracy: 1.0000 - val_loss: 0.0076 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 111/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1651 - accuracy: 0.9375 - val_loss: 0.0073 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 112/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0315 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 113/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0440 - accuracy: 0.9844 - val_loss: 0.0075 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 114/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0812 - accuracy: 0.9688 - val_loss: 0.0076 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 115/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0522 - accuracy: 0.9844 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 116/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0485 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 117/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0592 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 118/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0905 - accuracy: 0.9688 - val_loss: 0.0075 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 119/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0433 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 120/300
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0591 - accuracy: 0.9844 - val_loss: 0.0072 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  1e-05
# Epoch 121/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0375 - accuracy: 0.9844 - val_loss: 0.0073 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Learning rate:  5e-06
# Epoch 122/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0543 - accuracy: 0.9844 - val_loss: 0.0073 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 123/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0660 - accuracy: 0.9844 - val_loss: 0.0074 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 124/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0497 - accuracy: 0.9844 - val_loss: 0.0074 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 125/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1150 - accuracy: 0.9688 - val_loss: 0.0073 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 126/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0857 - accuracy: 0.9844 - val_loss: 0.0073 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 127/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1002 - accuracy: 0.9375 - val_loss: 0.0073 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 128/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0310 - accuracy: 0.9844 - val_loss: 0.0073 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 129/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0553 - accuracy: 0.9844 - val_loss: 0.0072 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 130/300
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1041 - accuracy: 0.9688 - val_loss: 0.0072 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 131/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0837 - accuracy: 0.9844 - val_loss: 0.0074 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 132/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0521 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 133/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0560 - accuracy: 0.9844 - val_loss: 0.0073 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 134/300
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1061 - accuracy: 0.9688 - val_loss: 0.0071 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 135/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0321 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 136/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0712 - accuracy: 0.9844 - val_loss: 0.0071 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 137/300
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0534 - accuracy: 0.9688 - val_loss: 0.0071 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 138/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0696 - accuracy: 0.9844 - val_loss: 0.0071 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 139/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0365 - accuracy: 0.9844 - val_loss: 0.0071 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 140/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0496 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 141/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0954 - accuracy: 0.9688 - val_loss: 0.0071 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 142/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0563 - accuracy: 0.9844 - val_loss: 0.0070 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 143/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0741 - accuracy: 0.9844 - val_loss: 0.0069 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 144/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0415 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 145/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0607 - accuracy: 0.9844 - val_loss: 0.0071 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 146/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0326 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 147/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0634 - accuracy: 0.9844 - val_loss: 0.0072 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 148/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0406 - accuracy: 0.9844 - val_loss: 0.0075 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 149/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0863 - accuracy: 0.9531 - val_loss: 0.0074 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 150/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0588 - accuracy: 0.9844 - val_loss: 0.0073 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 151/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0419 - accuracy: 0.9844 - val_loss: 0.0073 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 152/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0513 - accuracy: 0.9844 - val_loss: 0.0073 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 153/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0561 - accuracy: 0.9844 - val_loss: 0.0072 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 154/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0621 - accuracy: 0.9844 - val_loss: 0.0071 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 155/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0590 - accuracy: 0.9844 - val_loss: 0.0070 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 156/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0466 - accuracy: 0.9844 - val_loss: 0.0070 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 157/300
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0387 - accuracy: 0.9844 - val_loss: 0.0070 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 158/300
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0655 - accuracy: 0.9844 - val_loss: 0.0071 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 159/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0467 - accuracy: 0.9844 - val_loss: 0.0071 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 160/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0655 - accuracy: 0.9688 - val_loss: 0.0072 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 161/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1238 - accuracy: 0.9688 - val_loss: 0.0072 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 162/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0256 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 163/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1099 - accuracy: 0.9844 - val_loss: 0.0073 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 164/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0749 - accuracy: 0.9844 - val_loss: 0.0073 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 165/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0424 - accuracy: 0.9844 - val_loss: 0.0075 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 166/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0615 - accuracy: 0.9844 - val_loss: 0.0076 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 167/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0515 - accuracy: 0.9844 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 168/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0413 - accuracy: 0.9844 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 169/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0492 - accuracy: 0.9844 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 170/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0505 - accuracy: 0.9844 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 171/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0715 - accuracy: 0.9844 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 172/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0545 - accuracy: 0.9844 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 173/300
# 8/8 [==============================] - 0s 19ms/step - loss: 0.0299 - accuracy: 0.9844 - val_loss: 0.0082 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 174/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0531 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 175/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0638 - accuracy: 0.9844 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 176/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0367 - accuracy: 0.9844 - val_loss: 0.0081 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 177/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0849 - accuracy: 0.9844 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 178/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0350 - accuracy: 0.9844 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 179/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1922 - accuracy: 0.9531 - val_loss: 0.0077 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 180/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0394 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 181/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0365 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 182/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0476 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 183/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0803 - accuracy: 0.9844 - val_loss: 0.0075 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 184/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1328 - accuracy: 0.9844 - val_loss: 0.0076 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 185/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0630 - accuracy: 0.9844 - val_loss: 0.0077 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 186/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0705 - accuracy: 0.9688 - val_loss: 0.0076 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 187/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0733 - accuracy: 0.9688 - val_loss: 0.0076 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 188/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0774 - accuracy: 0.9688 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 189/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0327 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 190/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0979 - accuracy: 0.9688 - val_loss: 0.0088 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 191/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0443 - accuracy: 0.9844 - val_loss: 0.0087 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 192/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0307 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 193/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1082 - accuracy: 0.9688 - val_loss: 0.0086 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 194/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0633 - accuracy: 0.9844 - val_loss: 0.0084 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 195/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0636 - accuracy: 1.0000 - val_loss: 0.0083 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 196/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0615 - accuracy: 0.9844 - val_loss: 0.0082 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 197/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0784 - accuracy: 0.9688 - val_loss: 0.0082 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 198/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0325 - accuracy: 0.9844 - val_loss: 0.0083 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 199/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1094 - accuracy: 0.9688 - val_loss: 0.0084 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 200/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0684 - accuracy: 0.9688 - val_loss: 0.0089 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-06
# Epoch 201/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0348 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 1.0000 - lr: 5.0000e-06
# Learning rate:  5e-07
# Epoch 202/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0800 - accuracy: 0.9844 - val_loss: 0.0089 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 203/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0350 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 204/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0490 - accuracy: 0.9844 - val_loss: 0.0087 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 205/300
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0677 - accuracy: 0.9844 - val_loss: 0.0086 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 206/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0576 - accuracy: 0.9844 - val_loss: 0.0086 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 207/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0519 - accuracy: 0.9844 - val_loss: 0.0085 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 208/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0475 - accuracy: 0.9844 - val_loss: 0.0085 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 209/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0764 - accuracy: 0.9844 - val_loss: 0.0085 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 210/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0450 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 211/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0542 - accuracy: 0.9844 - val_loss: 0.0083 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 212/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0502 - accuracy: 0.9844 - val_loss: 0.0083 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 213/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0417 - accuracy: 0.9844 - val_loss: 0.0083 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 214/300
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0934 - accuracy: 0.9688 - val_loss: 0.0081 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 215/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0712 - accuracy: 0.9844 - val_loss: 0.0081 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 216/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0350 - accuracy: 0.9844 - val_loss: 0.0082 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 217/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0558 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 218/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.2516 - accuracy: 0.9375 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 219/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0313 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 220/300
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0352 - accuracy: 0.9844 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 221/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1213 - accuracy: 0.9375 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 222/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0453 - accuracy: 0.9844 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 223/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0926 - accuracy: 0.9688 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 224/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0500 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 225/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0343 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 226/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0344 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 227/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0689 - accuracy: 0.9844 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 228/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0550 - accuracy: 0.9844 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 229/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0629 - accuracy: 0.9844 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 230/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0342 - accuracy: 0.9844 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 231/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0359 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 232/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0666 - accuracy: 0.9844 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 233/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0413 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 234/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.3947 - accuracy: 0.8906 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 235/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0505 - accuracy: 0.9844 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 236/300
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1372 - accuracy: 0.9844 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 237/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0917 - accuracy: 0.9688 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 238/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0486 - accuracy: 0.9844 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 239/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0442 - accuracy: 0.9844 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 240/300
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0294 - accuracy: 0.9844 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 241/300
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0412 - accuracy: 0.9844 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 242/300
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0785 - accuracy: 0.9844 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 243/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0635 - accuracy: 0.9844 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 244/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0981 - accuracy: 0.9531 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 245/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0287 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 246/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0387 - accuracy: 0.9844 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 247/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0719 - accuracy: 0.9844 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 248/300
# 8/8 [==============================] - 0s 13ms/step - loss: 0.1125 - accuracy: 0.9531 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 249/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0326 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 250/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0953 - accuracy: 0.9688 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 251/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0357 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 252/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0313 - accuracy: 0.9844 - val_loss: 0.0081 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 253/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0441 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 254/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0717 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 255/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0429 - accuracy: 0.9844 - val_loss: 0.0081 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 256/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0444 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 257/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0408 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 258/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0470 - accuracy: 0.9844 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 259/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0973 - accuracy: 0.9688 - val_loss: 0.0081 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 260/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 261/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1073 - accuracy: 0.9688 - val_loss: 0.0082 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 262/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0688 - accuracy: 0.9844 - val_loss: 0.0081 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 263/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0449 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 264/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0478 - accuracy: 0.9844 - val_loss: 0.0082 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 265/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1152 - accuracy: 0.9688 - val_loss: 0.0082 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 266/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0533 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 267/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.1001 - accuracy: 0.9531 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 268/300
# 8/8 [==============================] - 0s 15ms/step - loss: 0.1029 - accuracy: 0.9688 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 269/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0406 - accuracy: 0.9844 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 270/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0554 - accuracy: 0.9844 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 271/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0580 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 272/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0596 - accuracy: 0.9844 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 273/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0810 - accuracy: 0.9688 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 274/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0453 - accuracy: 1.0000 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 275/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0635 - accuracy: 1.0000 - val_loss: 0.0077 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 276/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0410 - accuracy: 0.9844 - val_loss: 0.0077 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 277/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0473 - accuracy: 0.9844 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 278/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0422 - accuracy: 0.9844 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 279/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0357 - accuracy: 0.9844 - val_loss: 0.0078 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 280/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0353 - accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 281/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0261 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 282/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0625 - accuracy: 0.9844 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 283/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0527 - accuracy: 0.9844 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 284/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0587 - accuracy: 0.9844 - val_loss: 0.0079 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 285/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0257 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 286/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0596 - accuracy: 0.9844 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 287/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0338 - accuracy: 0.9844 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 288/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0257 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 289/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0353 - accuracy: 0.9844 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 290/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0557 - accuracy: 0.9844 - val_loss: 0.0080 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 291/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0276 - accuracy: 0.9844 - val_loss: 0.0081 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 292/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0448 - accuracy: 0.9844 - val_loss: 0.0081 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 293/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0429 - accuracy: 0.9844 - val_loss: 0.0081 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 294/300
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0704 - accuracy: 0.9844 - val_loss: 0.0081 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 295/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0430 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 296/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0545 - accuracy: 0.9844 - val_loss: 0.0081 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 297/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0442 - accuracy: 0.9844 - val_loss: 0.0081 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 298/300
# 8/8 [==============================] - 0s 16ms/step - loss: 0.0375 - accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 299/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000 - lr: 5.0000e-07
# Learning rate:  5e-07
# Epoch 300/300
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0433 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 1.0000 - lr: 5.0000e-07

# %%
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands
cap = cv2.VideoCapture(0)

# Use a list to store individual 1D arrays
sequential_list = []
with mp_hands.Hands(max_num_hands=2,
                    min_detection_confidence=0.5,
                    min_tracking_confidence=0.5) as hands:
    print(cap.isOpened())
    while cap.isOpened():
        success, image = cap.read()
        if not success:
            print("Ignoring empty camera frame.")

        image = cv2.cvtColor(cv2.flip(image, 1), cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        results = hands.process(image)

        # DETECT LANDMARKS
        if results.multi_hand_landmarks:
            # Append the values to the list
            sequential_list.append(landmark_to_dist_emb(results))
            # print(np.array(sequential_list).shape)

            jsonObj = MessageToJson(results.multi_hand_landmarks[0])
            lmk = json.loads(jsonObj)['landmark']
        else:
            # print("Hand Gesture Recognition Interrupted.")
            sequential_list.clear()
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                mp_drawing.draw_landmarks(
                    image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
        cv2.imshow('MediaPipe Hands', image)

        # Check if the length of the list exceeds 10
        if len(sequential_list) >= 10:
            # Convert the list to a 3D NumPy array
            sequential = np.expand_dims(np.array(sequential_list), axis=0)
            threshold = 0.5  # You can adjust this threshold based on your needs

            # Classify based on the threshold
            prediction = np.argmax(model.predict(
                sequential)[0])
            if prediction == 0:
                print("Egg")
            elif prediction == 1:
                print("Chicken")
            elif prediction == 2:
                print("Crab")
            elif prediction == 3:
                print("Bread")
            # Clear the list
            sequential_list.clear()

        if cv2.waitKey(5) & 0xFF == 27:
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# True
# 1/1 [==============================] - 2s 2s/step
# Egg
# 1/1 [==============================] - 0s 19ms/step
# Egg
# 1/1 [==============================] - 0s 20ms/step
# Bread
# 1/1 [==============================] - 0s 18ms/step
# Egg
# 1/1 [==============================] - 0s 18ms/step
# Egg
# 1/1 [==============================] - 0s 19ms/step
# Egg
# 1/1 [==============================] - 0s 18ms/step
# Egg
# 1/1 [==============================] - 0s 19ms/step
# Egg
# 1/1 [==============================] - 0s 18ms/step
# Egg
# 1/1 [==============================] - 0s 18ms/step
# Egg
# 1/1 [==============================] - 0s 19ms/step
# Egg
# 1/1 [==============================] - 0s 19ms/step
# Bread
# 1/1 [==============================] - 0s 18ms/step
# Bread
# 1/1 [==============================] - 0s 18ms/step
# Egg
# 1/1 [==============================] - 0s 19ms/step
# Bread
# 1/1 [==============================] - 0s 19ms/step
# Chicken
# 1/1 [==============================] - 0s 19ms/step
# Chicken
# 1/1 [==============================] - 0s 19ms/step
# Chicken
# 1/1 [==============================] - 0s 20ms/step
# Chicken
# 1/1 [==============================] - 0s 18ms/step
# Chicken
# 1/1 [==============================] - 0s 19ms/step
# Chicken
# 1/1 [==============================] - 0s 18ms/step
# Chicken
# 1/1 [==============================] - 0s 20ms/step
# Crab
# 1/1 [==============================] - 0s 19ms/step
# Crab
# 1/1 [==============================] - 0s 17ms/step
# Crab
# 1/1 [==============================] - 0s 18ms/step
# Crab
# 1/1 [==============================] - 0s 18ms/step
# Crab
# 1/1 [==============================] - 0s 18ms/step
# Crab
# 1/1 [==============================] - 0s 18ms/step
# Crab
# 1/1 [==============================] - 0s 18ms/step
# Crab
# 1/1 [==============================] - 0s 17ms/step
# Bread
# 1/1 [==============================] - 0s 18ms/step
# Bread
# 1/1 [==============================] - 0s 19ms/step
# Chicken
# 1/1 [==============================] - 0s 18ms/step
# Egg
# 1/1 [==============================] - 0s 19ms/step
# Egg
# 1/1 [==============================] - 0s 19ms/step
# Egg

# %% [markdown]
# ## Save Trained Model

# %%
model.save("fsl-pi.h5")
# Out:
# e:\Compilers\Python\3.11.1\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## Load Trained Model [Run This For Testing and Deployment Purposes]

# %% [markdown]
# #### Libraries

# %%
from keras.models import load_model
import pandas as pd
import numpy as np
from google.protobuf.json_format import MessageToJson
import cv2
import mediapipe as mp
import json

# %% [markdown]
# #### Load Model

# %%
trained_model = load_model('./fsl-pi.h5')

# %% [markdown]
# #### Feature Extractor for when getting realtime input data

# %%
def distance_between(p1_loc, p2_loc):
    jsonObj = MessageToJson(results.multi_hand_landmarks[0])
    lmk = json.loads(jsonObj)['landmark']
    p1 = pd.DataFrame(lmk).to_numpy()[p1_loc]
    p2 = pd.DataFrame(lmk).to_numpy()[p2_loc]
    squared_dist = np.sum((p1-p2)**2, axis=0)
    return np.sqrt(squared_dist)


def landmark_to_dist_emb(results):
    jsonObj = MessageToJson(results.multi_hand_landmarks[0])
    lmk = json.loads(jsonObj)['landmark']

    emb = np.array([
        # thumb to finger tip
        distance_between(4, 8),
        distance_between(4, 12),
        distance_between(4, 16),
        distance_between(4, 20),
        # wrist to finger tip
        distance_between(4, 0),
        distance_between(8, 0),
        distance_between(12, 0),
        distance_between(16, 0),
        distance_between(20, 0),
        # tip to tip (specific to this application)
        distance_between(8, 12),
        distance_between(12, 16),
        # within finger joint (detect bending)
        distance_between(1, 4),
        distance_between(8, 5),
        distance_between(12, 9),
        distance_between(16, 13),
        distance_between(20, 17),
        # distance from each tip to thumb joint
        distance_between(2, 8),
        distance_between(2, 12),
        distance_between(2, 16),
        distance_between(2, 20)
    ])
    # use np normalize, as min_max may create confusion that the closest fingers has 0 distance
    emb_norm = emb / np.linalg.norm(emb)
    return emb_norm

# %% [markdown]
# ## Deployment and Testing of Model

# %%
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands
cap = cv2.VideoCapture(0)

# Use a list to store individual 1D arrays
sequential_list = []
with mp_hands.Hands(max_num_hands=2,
                    min_detection_confidence=0.5,
                    min_tracking_confidence=0.5) as hands:
    print(cap.isOpened())
    while cap.isOpened():
        success, image = cap.read()
        if not success:
            print("Ignoring empty camera frame.")

        image = cv2.cvtColor(cv2.flip(image, 1), cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        results = hands.process(image)

        # DETECT LANDMARKS
        if results.multi_hand_landmarks:
            # Append the values to the list
            sequential_list.append(landmark_to_dist_emb(results))
            #print(np.array(sequential_list).shape)

            jsonObj = MessageToJson(results.multi_hand_landmarks[0])
            lmk = json.loads(jsonObj)['landmark']
        else:
            #print("Hand Gesture Recognition Interrupted.")
            sequential_list.clear()
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                mp_drawing.draw_landmarks(
                    image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
        cv2.imshow('MediaPipe Hands', image)

        # Check if the length of the list exceeds X Frames
        if len(sequential_list) >= 10:
            # Convert the list to a 3D NumPy array
            sequential = np.expand_dims(np.array(sequential_list), axis=0)
            # Assuming 'predictions' is the array [8.5479594e-05, 9.9991453e-01]
            threshold = 0.5  # You can adjust this threshold based on your needs

            # Classify based on the threshold
            prediction = np.argmax(trained_model.predict(
                sequential)[0])
            if prediction == 0:
                print("Egg")
            elif prediction == 1:
                print("Chicken")
            elif prediction == 2:
                print("Crab")
            elif prediction == 3:
                print("Bread")
            # Clear the list
            sequential_list.clear()

        if cv2.waitKey(5) & 0xFF == 27:
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# True
# 1/1 [==============================] - 1s 1s/step
# Egg
# 1/1 [==============================] - 0s 20ms/step
# Egg
# 1/1 [==============================] - 0s 19ms/step
# Egg
# 1/1 [==============================] - 0s 19ms/step
# Chicken
# 1/1 [==============================] - 0s 18ms/step
# Egg
# 1/1 [==============================] - 0s 19ms/step
# Bread
# 1/1 [==============================] - 0s 19ms/step
# Bread
# 1/1 [==============================] - 0s 18ms/step
# Bread
# 1/1 [==============================] - 0s 19ms/step
# Bread
# 1/1 [==============================] - 0s 19ms/step
# Bread
# 1/1 [==============================] - 0s 19ms/step
# Chicken
# 1/1 [==============================] - 0s 19ms/step
# Chicken
# 1/1 [==============================] - 0s 20ms/step
# Chicken
# 1/1 [==============================] - 0s 21ms/step
# Egg
# 1/1 [==============================] - 0s 18ms/step
# Bread
# 1/1 [==============================] - 0s 19ms/step
# Bread

# %% [markdown]
# ## Model Metrics and Quantization

# %%
model = load_model('./fsl-pi.h5')
model_path = './fsl-pi.h5'

# %% [markdown]
# #### Model Size

# %%
import os

model_size_bytes = os.path.getsize(model_path)
model_size_kb = model_size_bytes / 1024
model_size_mb = model_size_kb / 1024

print(f"Model size: {model_size_mb:.2f} MB")
# Out:
# Model size: 11.68 MB

# %% [markdown]
# #### Convert Model into TFLite

# %%
import tensorflow as tf


model = tf.keras.models.load_model("fsl-pi.h5")
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS, tf.lite.OpsSet.SELECT_TF_OPS]
converter._experimental_lower_tensor_list_ops = False
tflite_model = converter.convert()
with open('model.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\shuan\AppData\Local\Temp\tmpdk3vm9b9\assets
# INFO:tensorflow:Assets written to: C:\Users\shuan\AppData\Local\Temp\tmpdk3vm9b9\assets

# %% [markdown]
# #### Check TFLite Model Size

# %%
import os

model_size_bytes = os.path.getsize('model.tflite')
model_size_kb = model_size_bytes / 1024
model_size_mb = model_size_kb / 1024

print(f"Model size: {model_size_mb:.2f} MB")
# Out:
# Model size: 3.90 MB

# %%
import os
import tensorflow as tf

original_model = tf.keras.models.load_model('fsl-pi.h5')

converter = tf.lite.TFLiteConverter.from_keras_model(original_model)

converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS, tf.lite.OpsSet.SELECT_TF_OPS]
converter._experimental_lower_tensor_list_ops = False
converter.optimizations = [tf.lite.Optimize.DEFAULT]
quantized_tflite_model = converter.convert()
with open('quantized_model.tflite', 'wb') as f:
    f.write(quantized_tflite_model)
quantized_model_size_bytes = os.path.getsize('quantized_model.tflite')
quantized_model_size_kb = quantized_model_size_bytes / 1024
quantized_model_size_mb = quantized_model_size_kb / 1024
print(f"Quantized Model size: {quantized_model_size_mb:.2f} MB")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\shuan\AppData\Local\Temp\tmpl3o9j1yo\assets
# INFO:tensorflow:Assets written to: C:\Users\shuan\AppData\Local\Temp\tmpl3o9j1yo\assets
# Quantized Model size: 1.01 MB

# %% [markdown]
# #### Test Quantized Model

# %%
import tensorflow as tf

interpreter = tf.lite.Interpreter(model_path='./quantized_model.tflite')
interpreter.allocate_tensors()

# %%
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands
cap = cv2.VideoCapture(0)


sequential_list = []

with mp_hands.Hands(max_num_hands=2,
                    min_detection_confidence=0.5,
                    min_tracking_confidence=0.5) as hands:
    print(cap.isOpened())
    while cap.isOpened():
        success, image = cap.read()
        if not success:
            print("Ignoring empty camera frame.")

        image = cv2.cvtColor(cv2.flip(image, 1), cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        results = hands.process(image)


        if results.multi_hand_landmarks:
            sequential_list.append(landmark_to_dist_emb(results))
            jsonObj = MessageToJson(results.multi_hand_landmarks[0])
            lmk = json.loads(jsonObj)['landmark']
        else:
            sequential_list.clear()

        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                mp_drawing.draw_landmarks(
                    image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
        cv2.imshow('MediaPipe Hands', image)

        if len(sequential_list) >= 10:
            sequential = np.expand_dims(
                np.array(sequential_list), axis=0).astype(np.float32)

            interpreter.set_tensor(interpreter.get_input_details()[
                                0]['index'], sequential)
            interpreter.invoke()
            output = interpreter.get_tensor(
                interpreter.get_output_details()[0]['index'])
            prediction = np.argmax(output[0])
            if prediction == 0:
                print("Egg")
            elif prediction == 1:
                print("Chicken")
            elif prediction == 2:
                print("Crab")
            elif prediction == 3:
                print("Bread")

            sequential_list.clear()

        if cv2.waitKey(5) & 0xFF == 27:
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# True
# Egg
# Egg
# Bread
# Egg
# Egg
# Egg
# Egg
# Egg
# Bread
# Bread
# Bread
# Bread
# Bread
# Chicken
# Chicken
# Chicken
# Chicken
# Chicken
# Chicken
# Chicken
# Chicken
# Egg
# Chicken
# Chicken
# Bread
# Bread
# Bread
# Bread
# Bread
# Bread
# Egg
# Chicken
# Bread
# Bread
# Crab
# Crab
# Bread
